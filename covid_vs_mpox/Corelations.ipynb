# %%
# First cell - Import libraries and setup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import string
import nltk
import re
from textblob import TextBlob
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
from sklearn.preprocessing import LabelEncoder
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import plotly.express as px

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Second cell - Load Data
# COVID-19 Data
covid_df3 = pd.read_csv('/kaggle/input/covid19-twitter-dataset/Covid-19 Twitter Dataset (Apr-Jun 2021).csv')

# Combine COVID datasets
covid_df = pd.concat([covid_df3], ignore_index=True)

# Monkeypox Data
# Original monkeypox dataset
mpox_files = glob.glob('/kaggle/input/monkeypox-tweets/*.csv')
mpox_df1 = pd.concat(map(pd.read_csv, mpox_files), ignore_index=True)

# New monkeypox dataset
mpox_df2 = pd.read_csv('/kaggle/input/tweets-on-monkeypox/monkeypox.csv')

# New monkeypox dataset
mpox_df3 = pd.read_csv('/kaggle/input/monkeypox-tweets-data/monkeypox_tweets.csv')

# Combine monkeypox datasets
mpox_df = pd.concat([mpox_df1, mpox_df2, mpox_df3], ignore_index=True)

print("COVID-19 Dataset Shape:", covid_df.shape)
print("Monkeypox Dataset Shape:", mpox_df.shape)
# Out:
# COVID-19 Dataset Shape: (147475, 17)
# Monkeypox Dataset Shape: (106638, 40)

# %%
import pandas as pd
import glob

# Monkeypox Data
# Original monkeypox dataset - Add prefix to column names for each file
mpox_files = glob.glob('/kaggle/input/monkeypox-tweets/*.csv')
mpox_dfs = []
for idx, file in enumerate(mpox_files):
    df = pd.read_csv(file)
    df.columns = [f"file{idx}_{col}" for col in df.columns]  # Add dynamic 'fileX_' prefix
    mpox_dfs.append(df)
mpox_df1 = pd.concat(mpox_dfs, ignore_index=True)

# New monkeypox datasets - Add dynamic prefixes
mpox_df2 = pd.read_csv('/kaggle/input/tweets-on-monkeypox/monkeypox.csv')
mpox_df2.columns = [f"file{len(mpox_files)}_{col}" for col in mpox_df2.columns]  # Add 'fileX_' prefix

mpox_df3 = pd.read_csv('/kaggle/input/monkeypox-tweets-data/monkeypox_tweets.csv')
mpox_df3.columns = [f"file{len(mpox_files)+1}_{col}" for col in mpox_df3.columns]  # Add 'fileX_' prefix

# Combine monkeypox datasets
mpox_df = pd.concat([mpox_df1, mpox_df2, mpox_df3], ignore_index=True)

# Print dataset shapes and sample of column names to verify

print("Monkeypox Dataset Shape:", mpox_df.shape)
print("\nMpox DataFrame Columns:")
print(mpox_df.columns.tolist())  # Display column names to verify the prefixes
# Out:
# Monkeypox Dataset Shape: (106638, 212)
#
# Mpox DataFrame Columns:
# ['file0_Unnamed: 0', 'file0_date', 'file0_time', 'file0_id', 'file0_tweet', 'file0_language', 'file0_replies_count', 'file0_retweets_count', 'file0_likes_count', 'file1_Unnamed: 0', 'file1_date', 'file1_time', 'file1_id', 'file1_tweet', 'file1_language', 'file1_replies_count', 'file1_retweets_count', 'file1_likes_count', 'file2_Unnamed: 0', 'file2_date', 'file2_time', 'file2_id', 'file2_tweet', 'file2_language', 'file2_replies_count', 'file2_retweets_count', 'file2_likes_count', 'file3_Unnamed: 0', 'file3_date', 'file3_time', 'file3_id', 'file3_tweet', 'file3_language', 'file3_replies_count', 'file3_retweets_count', 'file3_likes_count', 'file4_Unnamed: 0', 'file4_date', 'file4_time', 'file4_id', 'file4_tweet', 'file4_language', 'file4_replies_count', 'file4_retweets_count', 'file4_likes_count', 'file5_Unnamed: 0', 'file5_date', 'file5_time', 'file5_id', 'file5_tweet', 'file5_language', 'file5_replies_count', 'file5_retweets_count', 'file5_likes_count', 'file6_Unnamed: 0', 'file6_date', 'file6_time', 'file6_id', 'file6_tweet', 'file6_language', 'file6_replies_count', 'file6_retweets_count', 'file6_likes_count', 'file7_Unnamed: 0', 'file7_date', 'file7_time', 'file7_id', 'file7_tweet', 'file7_language', 'file7_replies_count', 'file7_retweets_count', 'file7_likes_count', 'file8_Unnamed: 0', 'file8_date', 'file8_time', 'file8_id', 'file8_tweet', 'file8_language', 'file8_replies_count', 'file8_retweets_count', 'file8_likes_count', 'file9_Unnamed: 0', 'file9_date', 'file9_time', 'file9_id', 'file9_tweet', 'file9_language', 'file9_replies_count', 'file9_retweets_count', 'file9_likes_count', 'file10_Unnamed: 0', 'file10_date', 'file10_time', 'file10_id', 'file10_tweet', 'file10_language', 'file10_replies_count', 'file10_retweets_count', 'file10_likes_count', 'file11_Unnamed: 0', 'file11_date', 'file11_time', 'file11_id', 'file11_tweet', 'file11_language', 'file11_replies_count', 'file11_retweets_count', 'file11_likes_count', 'file12_Unnamed: 0', 'file12_date', 'file12_time', 'file12_id', 'file12_tweet', 'file12_language', 'file12_replies_count', 'file12_retweets_count', 'file12_likes_count', 'file13_Unnamed: 0', 'file13_date', 'file13_time', 'file13_id', 'file13_tweet', 'file13_language', 'file13_replies_count', 'file13_retweets_count', 'file13_likes_count', 'file14_Unnamed: 0', 'file14_date', 'file14_time', 'file14_id', 'file14_tweet', 'file14_language', 'file14_replies_count', 'file14_retweets_count', 'file14_likes_count', 'file15_id', 'file15_conversation_id', 'file15_created_at', 'file15_date', 'file15_time', 'file15_timezone', 'file15_user_id', 'file15_username', 'file15_name', 'file15_place', 'file15_tweet', 'file15_language', 'file15_mentions', 'file15_urls', 'file15_photos', 'file15_replies_count', 'file15_retweets_count', 'file15_likes_count', 'file15_hashtags', 'file15_cashtags', 'file15_link', 'file15_retweet', 'file15_quote_url', 'file15_video', 'file15_thumbnail', 'file15_near', 'file15_geo', 'file15_source', 'file15_user_rt_id', 'file15_user_rt', 'file15_retweet_id', 'file15_reply_to', 'file15_retweet_date', 'file15_translate', 'file15_trans_src', 'file15_trans_dest', 'file16_id', 'file16_conversation_id', 'file16_created_at', 'file16_date', 'file16_time', 'file16_timezone', 'file16_user_id', 'file16_username', 'file16_name', 'file16_place', 'file16_tweet', 'file16_language', 'file16_mentions', 'file16_urls', 'file16_photos', 'file16_replies_count', 'file16_retweets_count', 'file16_likes_count', 'file16_hashtags', 'file16_cashtags', 'file16_link', 'file16_retweet', 'file16_quote_url', 'file16_video', 'file16_thumbnail', 'file16_near', 'file16_geo', 'file16_source', 'file16_user_rt_id', 'file16_user_rt', 'file16_retweet_id', 'file16_reply_to', 'file16_retweet_date', 'file16_translate', 'file16_trans_src', 'file16_trans_dest', 'file17_Unnamed: 0', 'file17_text', 'file17_favourite_count', 'file17_retweet_count', 'file17_created_at']

# %%
# Third cell - Part 1: Check column names
print("COVID-19 DataFrame Columns:")
print(covid_df.columns.tolist())
print("\nMonkeypox DataFrame Columns:")
print(mpox_df.columns.tolist())
# Out:
# COVID-19 DataFrame Columns:
# ['id', 'created_at', 'source', 'original_text', 'lang', 'favorite_count', 'retweet_count', 'original_author', 'hashtags', 'user_mentions', 'place', 'clean_tweet', 'compound', 'neg', 'neu', 'pos', 'sentiment']
#
# Monkeypox DataFrame Columns:
# ['file0_Unnamed: 0', 'file0_date', 'file0_time', 'file0_id', 'file0_tweet', 'file0_language', 'file0_replies_count', 'file0_retweets_count', 'file0_likes_count', 'file1_Unnamed: 0', 'file1_date', 'file1_time', 'file1_id', 'file1_tweet', 'file1_language', 'file1_replies_count', 'file1_retweets_count', 'file1_likes_count', 'file2_Unnamed: 0', 'file2_date', 'file2_time', 'file2_id', 'file2_tweet', 'file2_language', 'file2_replies_count', 'file2_retweets_count', 'file2_likes_count', 'file3_Unnamed: 0', 'file3_date', 'file3_time', 'file3_id', 'file3_tweet', 'file3_language', 'file3_replies_count', 'file3_retweets_count', 'file3_likes_count', 'file4_Unnamed: 0', 'file4_date', 'file4_time', 'file4_id', 'file4_tweet', 'file4_language', 'file4_replies_count', 'file4_retweets_count', 'file4_likes_count', 'file5_Unnamed: 0', 'file5_date', 'file5_time', 'file5_id', 'file5_tweet', 'file5_language', 'file5_replies_count', 'file5_retweets_count', 'file5_likes_count', 'file6_Unnamed: 0', 'file6_date', 'file6_time', 'file6_id', 'file6_tweet', 'file6_language', 'file6_replies_count', 'file6_retweets_count', 'file6_likes_count', 'file7_Unnamed: 0', 'file7_date', 'file7_time', 'file7_id', 'file7_tweet', 'file7_language', 'file7_replies_count', 'file7_retweets_count', 'file7_likes_count', 'file8_Unnamed: 0', 'file8_date', 'file8_time', 'file8_id', 'file8_tweet', 'file8_language', 'file8_replies_count', 'file8_retweets_count', 'file8_likes_count', 'file9_Unnamed: 0', 'file9_date', 'file9_time', 'file9_id', 'file9_tweet', 'file9_language', 'file9_replies_count', 'file9_retweets_count', 'file9_likes_count', 'file10_Unnamed: 0', 'file10_date', 'file10_time', 'file10_id', 'file10_tweet', 'file10_language', 'file10_replies_count', 'file10_retweets_count', 'file10_likes_count', 'file11_Unnamed: 0', 'file11_date', 'file11_time', 'file11_id', 'file11_tweet', 'file11_language', 'file11_replies_count', 'file11_retweets_count', 'file11_likes_count', 'file12_Unnamed: 0', 'file12_date', 'file12_time', 'file12_id', 'file12_tweet', 'file12_language', 'file12_replies_count', 'file12_retweets_count', 'file12_likes_count', 'file13_Unnamed: 0', 'file13_date', 'file13_time', 'file13_id', 'file13_tweet', 'file13_language', 'file13_replies_count', 'file13_retweets_count', 'file13_likes_count', 'file14_Unnamed: 0', 'file14_date', 'file14_time', 'file14_id', 'file14_tweet', 'file14_language', 'file14_replies_count', 'file14_retweets_count', 'file14_likes_count', 'file15_id', 'file15_conversation_id', 'file15_created_at', 'file15_date', 'file15_time', 'file15_timezone', 'file15_user_id', 'file15_username', 'file15_name', 'file15_place', 'file15_tweet', 'file15_language', 'file15_mentions', 'file15_urls', 'file15_photos', 'file15_replies_count', 'file15_retweets_count', 'file15_likes_count', 'file15_hashtags', 'file15_cashtags', 'file15_link', 'file15_retweet', 'file15_quote_url', 'file15_video', 'file15_thumbnail', 'file15_near', 'file15_geo', 'file15_source', 'file15_user_rt_id', 'file15_user_rt', 'file15_retweet_id', 'file15_reply_to', 'file15_retweet_date', 'file15_translate', 'file15_trans_src', 'file15_trans_dest', 'file16_id', 'file16_conversation_id', 'file16_created_at', 'file16_date', 'file16_time', 'file16_timezone', 'file16_user_id', 'file16_username', 'file16_name', 'file16_place', 'file16_tweet', 'file16_language', 'file16_mentions', 'file16_urls', 'file16_photos', 'file16_replies_count', 'file16_retweets_count', 'file16_likes_count', 'file16_hashtags', 'file16_cashtags', 'file16_link', 'file16_retweet', 'file16_quote_url', 'file16_video', 'file16_thumbnail', 'file16_near', 'file16_geo', 'file16_source', 'file16_user_rt_id', 'file16_user_rt', 'file16_retweet_id', 'file16_reply_to', 'file16_retweet_date', 'file16_translate', 'file16_trans_src', 'file16_trans_dest', 'file17_Unnamed: 0', 'file17_text', 'file17_favourite_count', 'file17_retweet_count', 'file17_created_at']

# %%
'''print("\nMpox DataFrame Columns:")
for column in mpox_df.columns:
    print(column)'''
# Out:
# 'print("\nMpox DataFrame Columns:")\nfor column in mpox_df.columns:\n    print(column)'

# %%
print('Rows and columns in training dataset covid : ',covid_df.shape)
print('Rows and columns in training dataset mpox : ',mpox_df.shape)
print("Monkeypox Dataset Shape:", mpox_df.shape)
# Out:
# Rows and columns in training dataset covid :  (147475, 17)
# Rows and columns in training dataset mpox :  (106638, 212)
# Monkeypox Dataset Shape: (106638, 212)

# %%
print('Rows and columns in training dataset mpox : ',mpox_df.shape)
# Out:
# Rows and columns in training dataset mpox :  (106638, 212)

# %%
# Rename 'file16_text' to 'processed_file16_text'
mpox_df.rename(columns={'file17_text': 'file17_tweet'}, inplace=True)

'''print("\nMonkeypox DataFrame Columns:")
for column in mpox_df.columns:
    print(column)'''
# Out:
# 'print("\nMonkeypox DataFrame Columns:")\nfor column in mpox_df.columns:\n    print(column)'

# %%
print('Rows and columns in training dataset covid : ',covid_df.shape)
print('Rows and columns in training dataset mpox : ',mpox_df.shape)
# Out:
# Rows and columns in training dataset covid :  (147475, 17)
# Rows and columns in training dataset mpox :  (106638, 212)

# %%
import nltk
import re
import emoji
import unicodedata
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    """Clean and preprocess text data comprehensively."""
    try:
        # Step 1: Convert to lowercase and string format
        text = str(text).lower()

        # Step 2: Normalize Unicode text
        text = unicodedata.normalize('NFKC', text).encode('ascii', 'ignore').decode('utf-8')

        # Step 3: Convert emojis to text
        text = emoji.demojize(text)

        # Step 4: Define unwanted patterns
        unwanted_patterns = [
            r'Ã³', r'±', r'à¤•', r'à¤¨', r'à¤²', r'à¤¹à¤²à¤•', r'à¤®', r'à¤•à¤ªà¤¯à¤Ÿà¤°',
            r'à¤µ', r'à¤•à¤«', r'à¤®à¤¶à¤¨', r'à¤¸', r'à¤­', r'à¤«à¤²', r'à¤¸à¤•à¤¤', r'à¤¹',
            r'à¤µà¤¯à¤°à¤¸', r'à¤¸à¤•à¤°à¤®à¤¤', r'à¤µà¤¯à¤•à¤¤', r'à¤œà¤¨à¤µà¤°',
            r'à¤¸', r'à¤°à¤¹', r'Ãª', r'Ã©', r'Ø³Ø¬Ù„Øª Ø¥ÙŠØ·Ø§Ù„ÙŠØ§ Ø§Ù„ÙŠÙˆÙ…',
            r'TÃ¼', r'bÃ¼yÃ¼tmÃ¼ÅŸ', r'Ã§Ã', r'oÃ¹', r'Ãº', r'Ã¨', r'nan'
        ]

        # Step 5: Remove unwanted patterns using regex
        for pattern in unwanted_patterns:
            text = re.sub(pattern, '', text)

        # Step 6: Remove URLs, mentions, and hashtags
        text = re.sub(r'http\S+|www\S+|https\S+', '', text)  # URLs
        text = re.sub(r'@\w+', '', text)  # Mentions
        text = re.sub(r'#\w+', '', text)  # Hashtags

        # Step 7: Remove punctuations and numeric words
        text = re.sub(r'[^\w\s]', '', text)  # Punctuations
        text = re.sub(r'\w*\d\w*', '', text)  # Words with numbers

        # Step 8: Tokenize text
        tokens = word_tokenize(text)

        # Step 9: Remove stopwords
        stop_words = set(stopwords.words('english'))
        custom_stopwords = {
            'rt', 'amp', 'via', 'like', 'get', 'would', 'also', 'covid',
            'covid19', 'coronavirus', 'corona', 'virus', 'monkeypox', 'mpox',
            'pox', 'monkey'
        }
        stop_words.update(custom_stopwords)
        tokens = [word for word in tokens if word not in stop_words]

        # Step 10: Reconstruct the cleaned text
        text = ' '.join(tokens).strip()

        return text
    except Exception as e:
        print(f"Error in text preprocessing: {str(e)}")
        return text
        

print("Applying enhanced preprocessing with emoji conversion, hashtag, mention, and stopword removal...")

# List of columns to preprocess
covid_columns_to_process = ['clean_tweet']
mpox_columns_to_process = ['file0_tweet', 'file1_tweet', 'file2_tweet', 'file3_tweet', 'file4_tweet',
                           'file5_tweet', 'file6_tweet', 'file7_tweet', 'file8_tweet', 'file9_tweet',
                           'file10_tweet', 'file11_tweet', 'file12_tweet', 'file13_tweet', 'file14_tweet',
                           'file15_tweet', 'file17_tweet', 'file16_tweet']

# Apply preprocessing to multiple columns
for col in covid_columns_to_process:
    covid_df[f'processed_{col}'] = covid_df[col].apply(preprocess_text)

for col in mpox_columns_to_process:
    mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)

print("\nSample COVID processed text:")
print(covid_df[[f'processed_{col}' for col in covid_columns_to_process]].head())

print("\nSample Monkeypox processed text:")
print(mpox_df[[f'processed_{col}' for col in mpox_columns_to_process]].head())
# Out:
# Applying enhanced preprocessing with emoji conversion, hashtag, mention, and stopword removal...
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)
# Sample COVID processed text:
#                                processed_clean_tweet
# 0  work close indian govern rapidli deploy addit ...
# 1        flip flop fauci admit outdoor transmiss low
# 2  hi twitter tim man white hous suppli coordin l...
# 3  pray countri battl worst surg world wit let ir...
# 4        rapid invest nurs strengthen global respons
#
# Sample Monkeypox processed text:
#                                processed_file0_tweet processed_file1_tweet  \
# 0  theyre useful vice lords black gangster discip...
# 1                         explainer research roundup
# 2  hocl makersim learning basic chem stung twice ...
# 3   la lleg la comunidad gay porn star tuitera limea
# 4  many see us one advanced countries world yet l...
#
#   processed_file2_tweet processed_file3_tweet processed_file4_tweet  \
# 0
# 1
# 2
# 3
# 4
#
#   processed_file5_tweet processed_file6_tweet processed_file7_tweet  \
# 0
# 1
# 2
# 3
# 4
#
#   processed_file8_tweet processed_file9_tweet processed_file10_tweet  \
# 0
# 1
# 2
# 3
# 4
#
#   processed_file11_tweet processed_file12_tweet processed_file13_tweet  \
# 0
# 1
# 2
# 3
# 4
#
#   processed_file14_tweet processed_file15_tweet processed_file17_tweet  \
# 0
# 1
# 2
# 3
# 4
#
#   processed_file16_tweet
# 0
# 1
# 2
# 3
# 4
# /tmp/ipykernel_36/3114219200.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df[f'processed_{col}'] = mpox_df[col].apply(preprocess_text)

# %%
# Combine all processed text columns into a single column for COVID dataset
covid_df['processed_text_covid'] = covid_df[[f'processed_{col}' for col in covid_columns_to_process]].apply(lambda row: ' '.join(row.values), axis=1)

print("\nSample combined processed text for COVID dataset:")
print(covid_df['processed_text_covid'].head())

# Combine all processed text columns into a single column for Monkeypox dataset
mpox_df['processed_text_mpox'] = mpox_df[[f'processed_{col}' for col in mpox_columns_to_process]].apply(lambda row: ' '.join(row.values), axis=1)

print("\nSample combined processed text for Monkeypox dataset:")
print(mpox_df['processed_text_mpox'].head())
# Out:
# Sample combined processed text for COVID dataset:
# 0    work close indian govern rapidli deploy addit ...
# 1          flip flop fauci admit outdoor transmiss low
# 2    hi twitter tim man white hous suppli coordin l...
# 3    pray countri battl worst surg world wit let ir...
# 4          rapid invest nurs strengthen global respons
# Name: processed_text_covid, dtype: object
#
# Sample combined processed text for Monkeypox dataset:
# 0    theyre useful vice lords black gangster discip...
# 1          explainer research roundup
# 2    hocl makersim learning basic chem stung twice ...
# 3    la lleg la comunidad gay porn star tuitera lim...
# 4    many see us one advanced countries world yet l...
# Name: processed_text_mpox, dtype: object
# /tmp/ipykernel_36/3263498616.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df['processed_text_mpox'] = mpox_df[[f'processed_{col}' for col in mpox_columns_to_process]].apply(lambda row: ' '.join(row.values), axis=1)

# %%
# Save the combined processed text columns to CSV files
covid_df[['processed_text_covid']].to_csv('/kaggle/working/combined_processed_covid_tweets.csv', index=False)
mpox_df[['processed_text_mpox']].to_csv('/kaggle/working/combined_processed_mpox_tweets.csv', index=False)

print("Combined processed text files have been saved to CSV.")
# Out:
# Combined processed text files have been saved to CSV.

# %%
print('Rows and columns in training dataset covid : ',covid_df.shape)
print('Rows and columns in training dataset mpox : ',mpox_df.shape)
# Out:
# Rows and columns in training dataset covid :  (147475, 19)
# Rows and columns in training dataset mpox :  (106638, 231)

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
import nltk


# Sample dataset (replace this with your dataset)
covid_df['processed_text_covid']

# Function to calculate word frequency
def calculate_word_frequency(text_series):
    """Calculate word frequency from a pandas series of text."""
    all_words = []
    for text in text_series:
        words = word_tokenize(str(text).lower())  # Tokenize and convert to lowercase
        all_words.extend(words)
    
    return Counter(all_words)

# Calculate word frequency
word_frequency = calculate_word_frequency(covid_df['processed_text_covid'])

# Display the 10 most common words
print("Top 10 Most Common Words:")
print(word_frequency.most_common(10))

# Create a bar plot of the top 10 words
top_words = word_frequency.most_common(10)
words, counts = zip(*top_words)

plt.figure(figsize=(10, 6))
plt.bar(words, counts, color='skyblue')
plt.title('Top 10 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequency)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud')
plt.show()

# Tokenize and count word frequencies
covid_df['temp'] = covid_df['processed_text_covid'].apply(lambda x: str(x).split())
top = Counter([item for sublist in covid_df['temp'] for item in sublist])

# Create DataFrame for top 10 words
temp = pd.DataFrame(top.most_common(10))
temp.columns = ['Common_words', 'Frequency']

# Display with gradient styling
temp_styled = temp.style.background_gradient(cmap='Purples')
temp_styled
# Out:
# Top 10 Most Common Words:
# [('vaccin', 30507), ('new', 12009), ('case', 11608), ('peopl', 8467), ('pandem', 6424), ('death', 6365), ('health', 6139), ('india', 6095), ('report', 6007), ('test', 5687)]
# <style type="text/css">
# #T_9630b_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_9630b_row1_col1 {
#   background-color: #d9d9ea;
#   color: #000000;
# }
# #T_9630b_row2_col1 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_9630b_row3_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_9630b_row4_col1 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_9630b_row5_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_9630b_row6_col1, #T_9630b_row7_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_9630b_row8_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_9630b_row9_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_9630b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9630b_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_9630b_level0_col1" class="col_heading level0 col1" >Frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9630b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9630b_row0_col0" class="data row0 col0" >vaccin</td>
#       <td id="T_9630b_row0_col1" class="data row0 col1" >30507</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9630b_row1_col0" class="data row1 col0" >new</td>
#       <td id="T_9630b_row1_col1" class="data row1 col1" >12009</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9630b_row2_col0" class="data row2 col0" >case</td>
#       <td id="T_9630b_row2_col1" class="data row2 col1" >11608</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9630b_row3_col0" class="data row3 col0" >peopl</td>
#       <td id="T_9630b_row3_col1" class="data row3 col1" >8467</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9630b_row4_col0" class="data row4 col0" >pandem</td>
#       <td id="T_9630b_row4_col1" class="data row4 col1" >6424</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9630b_row5_col0" class="data row5 col0" >death</td>
#       <td id="T_9630b_row5_col1" class="data row5 col1" >6365</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9630b_row6_col0" class="data row6 col0" >health</td>
#       <td id="T_9630b_row6_col1" class="data row6 col1" >6139</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9630b_row7_col0" class="data row7 col0" >india</td>
#       <td id="T_9630b_row7_col1" class="data row7 col1" >6095</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9630b_row8_col0" class="data row8 col0" >report</td>
#       <td id="T_9630b_row8_col1" class="data row8 col1" >6007</td>
#     </tr>
#     <tr>
#       <th id="T_9630b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9630b_row9_col0" class="data row9 col0" >test</td>
#       <td id="T_9630b_row9_col1" class="data row9 col1" >5687</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
import nltk


# Sample dataset (replace this with your dataset)
mpox_df['processed_text_mpox']

# Function to calculate word frequency
def calculate_word_frequency(text_series):
    """Calculate word frequency from a pandas series of text."""
    all_words = []
    for text in text_series:
        words = word_tokenize(str(text).lower())  # Tokenize and convert to lowercase
        all_words.extend(words)
    
    return Counter(all_words)

# Calculate word frequency
word_frequency = calculate_word_frequency(mpox_df['processed_text_mpox'])

# Display the 10 most common words
print("Top 10 Most Common Words:")
print(word_frequency.most_common(10))

# Create a bar plot of the top 10 words
top_words = word_frequency.most_common(10)
words, counts = zip(*top_words)

plt.figure(figsize=(10, 6))
plt.bar(words, counts, color='skyblue')
plt.title('Top 10 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequency)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud')
plt.show()

# Tokenize and count word frequencies
mpox_df['temp'] = mpox_df['processed_text_mpox'].apply(lambda x: str(x).split())
top = Counter([item for sublist in mpox_df['temp'] for item in sublist])

# Create DataFrame for top 10 words
temp = pd.DataFrame(top.most_common(10))
temp.columns = ['Common_words', 'Frequency']

# Display with gradient styling
temp_styled = temp.style.background_gradient(cmap='Purples')
temp_styled
# Out:
# Top 10 Most Common Words:
# [('cases', 8485), ('vaccine', 8072), ('de', 6407), ('health', 6134), ('people', 5906), ('new', 5650), ('us', 5472), ('case', 4598), ('first', 4398), ('gay', 4100)]
# /tmp/ipykernel_36/597264567.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df['temp'] = mpox_df['processed_text_mpox'].apply(lambda x: str(x).split())
# <style type="text/css">
# #T_0c398_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_0c398_row1_col1 {
#   background-color: #4f1d8b;
#   color: #f1f1f1;
# }
# #T_0c398_row2_col1 {
#   background-color: #9894c5;
#   color: #f1f1f1;
# }
# #T_0c398_row3_col1 {
#   background-color: #a7a4ce;
#   color: #f1f1f1;
# }
# #T_0c398_row4_col1 {
#   background-color: #b3b3d6;
#   color: #000000;
# }
# #T_0c398_row5_col1 {
#   background-color: #c1c2df;
#   color: #000000;
# }
# #T_0c398_row6_col1 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_0c398_row7_col1 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_0c398_row8_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_0c398_row9_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_0c398">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c398_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_0c398_level0_col1" class="col_heading level0 col1" >Frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c398_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c398_row0_col0" class="data row0 col0" >cases</td>
#       <td id="T_0c398_row0_col1" class="data row0 col1" >8482</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c398_row1_col0" class="data row1 col0" >vaccine</td>
#       <td id="T_0c398_row1_col1" class="data row1 col1" >8071</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c398_row2_col0" class="data row2 col0" >de</td>
#       <td id="T_0c398_row2_col1" class="data row2 col1" >6407</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c398_row3_col0" class="data row3 col0" >health</td>
#       <td id="T_0c398_row3_col1" class="data row3 col1" >6134</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c398_row4_col0" class="data row4 col0" >people</td>
#       <td id="T_0c398_row4_col1" class="data row4 col1" >5906</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c398_row5_col0" class="data row5 col0" >new</td>
#       <td id="T_0c398_row5_col1" class="data row5 col1" >5649</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c398_row6_col0" class="data row6 col0" >us</td>
#       <td id="T_0c398_row6_col1" class="data row6 col1" >5471</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c398_row7_col0" class="data row7 col0" >case</td>
#       <td id="T_0c398_row7_col1" class="data row7 col1" >4597</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c398_row8_col0" class="data row8 col0" >first</td>
#       <td id="T_0c398_row8_col1" class="data row8 col1" >4398</td>
#     </tr>
#     <tr>
#       <th id="T_0c398_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c398_row9_col0" class="data row9 col0" >gay</td>
#       <td id="T_0c398_row9_col1" class="data row9 col1" >4100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# DATA_PROCESSING_COVID

# %%
# Import dependencies
from transformers import pipeline
import numpy as np
import pandas as pd
from tqdm import tqdm

# ===============================
# Load GoEmotions Pipeline
# ===============================
classifier = pipeline(
    "text-classification", 
    model="j-hartmann/emotion-english-distilroberta-base",
    return_all_scores=True
)

# Emotion → Sentiment Mapping
positive_emotions = {'admiration', 'amusement', 'approval', 'caring', 'desire', 'excitement', 'gratitude', 'joy', 'love', 'optimism', 'pride', 'relief'}
negative_emotions = {'anger', 'annoyance', 'confusion', 'disappointment', 'disapproval', 'disgust', 'embarrassment', 'fear', 'grief', 'nervousness', 'remorse', 'sadness'}
neutral_emotions = {'curiosity', 'realization', 'surprise', 'neutral'}

def get_goemotion_sentiment(text):
    try:
        text = str(text)
        if len(text) < 2:
            return 0.0, 'neutral'
        
        result = classifier(text)[0]
        emotion_scores = {entry['label']: entry['score'] for entry in result}

        pos_score = sum(emotion_scores.get(e, 0) for e in positive_emotions)
        neg_score = sum(emotion_scores.get(e, 0) for e in negative_emotions)
        neu_score = sum(emotion_scores.get(e, 0) for e in neutral_emotions)

        # Decide sentiment label
        if max(pos_score, neg_score, neu_score) == pos_score:
            sentiment = 'positive'
        elif max(pos_score, neg_score, neu_score) == neg_score:
            sentiment = 'negative'
        else:
            sentiment = 'neutral'

        # Optionally return polarity score (pos - neg)
        polarity = pos_score - neg_score
        return polarity, sentiment

    except Exception as e:
        print(f"Error: {str(e)}")
        return 0.0, 'neutral'

# ===============================
# Apply Sentiment Analysis
# ===============================

print("Applying GoEmotions sentiment analysis (emotion to sentiment)...")
batch_size = 32

# COVID tweets
covid_results = []
for i in tqdm(range(0, len(covid_df), batch_size), desc="Processing COVID tweets"):
    batch = covid_df['processed_text_covid'].iloc[i:i+batch_size]
    results = [get_goemotion_sentiment(text) for text in batch]
    covid_results.extend(results)
covid_df['covid_polarity'], covid_df['covid_sentiment'] = zip(*covid_results)

# MPOX tweets
mpox_results = []
for i in tqdm(range(0, len(mpox_df), batch_size), desc="Processing Monkeypox tweets"):
    batch = mpox_df['processed_text_mpox'].iloc[i:i+batch_size]
    results = [get_goemotion_sentiment(text) for text in batch]
    mpox_results.extend(results)
mpox_df['mpox_polarity'], mpox_df['mpox_sentiment'] = zip(*mpox_results)

print("\nSentiment analysis complete!")

# ===============================
# (Optional) Save Results
# ===============================
# covid_df.to_csv("covid_goemotion_sentiment_output.csv", index=False)
# mpox_df.to_csv("mpox_goemotion_sentiment_output.csv", index=False)
# Out:
# 2025-07-17 15:22:04.872953: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752765725.073517      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752765725.128920      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Applying GoEmotions sentiment analysis (emotion to sentiment)...
# Processing COVID tweets:   0%|          | 0/4609 [00:00<?, ?it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#
# Processing COVID tweets:   0%|          | 1/4609 [00:00<1:14:36,  1.03it/s]
# Processing COVID tweets:   0%|          | 2/4609 [00:01<44:54,  1.71it/s]
# Processing COVID tweets:   0%|          | 3/4609 [00:01<32:58,  2.33it/s]
# Processing COVID tweets:   0%|          | 4/4609 [00:01<24:33,  3.12it/s]
# Processing COVID tweets:   0%|          | 5/4609 [00:01<19:47,  3.88it/s]
# Processing COVID tweets:   0%|          | 6/4609 [00:01<17:07,  4.48it/s]
# Processing COVID tweets:   0%|          | 7/4609 [00:02<15:22,  4.99it/s]
# Processing COVID tweets:   0%|          | 8/4609 [00:02<14:05,  5.44it/s]
# Processing COVID tweets:   0%|          | 9/4609 [00:02<14:05,  5.44it/s]
# Processing COVID tweets:   0%|          | 10/4609 [00:02<13:26,  5.70it/s]
# Processing COVID tweets:   0%|          | 11/4609 [00:02<12:49,  5.98it/s]
# Processing COVID tweets:   0%|          | 12/4609 [00:02<12:21,  6.20it/s]
# Processing COVID tweets:   0%|          | 13/4609 [00:03<12:08,  6.31it/s]
# Processing COVID tweets:   0%|          | 14/4609 [00:03<11:55,  6.42it/s]
# Processing COVID tweets:   0%|          | 15/4609 [00:03<11:48,  6.49it/s]
# Processing COVID tweets:   0%|          | 16/4609 [00:03<11:46,  6.50it/s]
# Processing COVID tweets:   0%|          | 17/4609 [00:03<11:47,  6.49it/s]
# Processing COVID tweets:   0%|          | 18/4609 [00:03<12:13,  6.26it/s]
# Processing COVID tweets:   0%|          | 19/4609 [00:04<11:52,  6.44it/s]
# Processing COVID tweets:   0%|          | 20/4609 [00:04<11:47,  6.49it/s]
# Processing COVID tweets:   0%|          | 21/4609 [00:04<11:43,  6.52it/s]
# Processing COVID tweets:   0%|          | 22/4609 [00:04<11:43,  6.52it/s]
# Processing COVID tweets:   0%|          | 23/4609 [00:04<12:02,  6.35it/s]
# Processing COVID tweets:   1%|          | 24/4609 [00:04<11:57,  6.39it/s]
# Processing COVID tweets:   1%|          | 25/4609 [00:04<11:45,  6.50it/s]
# Processing COVID tweets:   1%|          | 26/4609 [00:05<11:38,  6.56it/s]
# Processing COVID tweets:   1%|          | 27/4609 [00:05<11:32,  6.62it/s]
# Processing COVID tweets:   1%|          | 28/4609 [00:05<11:21,  6.72it/s]
# Processing COVID tweets:   1%|          | 29/4609 [00:05<11:17,  6.76it/s]
# Processing COVID tweets:   1%|          | 30/4609 [00:05<11:18,  6.75it/s]
# Processing COVID tweets:   1%|          | 31/4609 [00:05<11:12,  6.81it/s]
# Processing COVID tweets:   1%|          | 32/4609 [00:05<11:14,  6.78it/s]
# Processing COVID tweets:   1%|          | 33/4609 [00:06<11:18,  6.75it/s]
# Processing COVID tweets:   1%|          | 34/4609 [00:06<11:22,  6.70it/s]
# Processing COVID tweets:   1%|          | 35/4609 [00:06<11:34,  6.59it/s]
# Processing COVID tweets:   1%|          | 36/4609 [00:06<11:35,  6.57it/s]
# Processing COVID tweets:   1%|          | 37/4609 [00:06<11:32,  6.60it/s]
# Processing COVID tweets:   1%|          | 38/4609 [00:06<11:26,  6.65it/s]
# Processing COVID tweets:   1%|          | 39/4609 [00:07<11:23,  6.69it/s]
# Processing COVID tweets:   1%|          | 40/4609 [00:07<11:25,  6.66it/s]
# Processing COVID tweets:   1%|          | 41/4609 [00:07<11:18,  6.73it/s]
# Processing COVID tweets:   1%|          | 42/4609 [00:07<11:22,  6.69it/s]
# Processing COVID tweets:   1%|          | 43/4609 [00:07<11:24,  6.67it/s]
# Processing COVID tweets:   1%|          | 44/4609 [00:07<11:18,  6.72it/s]
# Processing COVID tweets:   1%|          | 45/4609 [00:07<11:14,  6.77it/s]
# Processing COVID tweets:   1%|          | 46/4609 [00:08<11:56,  6.36it/s]
# Processing COVID tweets:   1%|          | 47/4609 [00:08<12:57,  5.86it/s]
# Processing COVID tweets:   1%|          | 48/4609 [00:08<13:43,  5.54it/s]
# Processing COVID tweets:   1%|          | 49/4609 [00:08<14:44,  5.16it/s]
# Processing COVID tweets:   1%|          | 50/4609 [00:08<15:09,  5.01it/s]
# Processing COVID tweets:   1%|          | 51/4609 [00:09<15:10,  5.01it/s]
# Processing COVID tweets:   1%|          | 52/4609 [00:09<14:02,  5.41it/s]
# Processing COVID tweets:   1%|          | 53/4609 [00:09<13:20,  5.69it/s]
# Processing COVID tweets:   1%|          | 54/4609 [00:09<12:46,  5.94it/s]
# Processing COVID tweets:   1%|          | 55/4609 [00:09<12:19,  6.15it/s]
# Processing COVID tweets:   1%|          | 56/4609 [00:09<11:57,  6.34it/s]
# Processing COVID tweets:   1%|          | 57/4609 [00:10<11:42,  6.48it/s]
# Processing COVID tweets:   1%|▏         | 58/4609 [00:10<11:20,  6.69it/s]
# Processing COVID tweets:   1%|▏         | 59/4609 [00:10<11:22,  6.67it/s]
# Processing COVID tweets:   1%|▏         | 60/4609 [00:10<11:20,  6.69it/s]
# Processing COVID tweets:   1%|▏         | 61/4609 [00:10<11:29,  6.59it/s]
# Processing COVID tweets:   1%|▏         | 62/4609 [00:10<11:31,  6.58it/s]
# Processing COVID tweets:   1%|▏         | 63/4609 [00:10<11:28,  6.60it/s]
# Processing COVID tweets:   1%|▏         | 64/4609 [00:11<11:23,  6.65it/s]
# Processing COVID tweets:   1%|▏         | 65/4609 [00:11<11:45,  6.44it/s]
# Processing COVID tweets:   1%|▏         | 66/4609 [00:11<12:17,  6.16it/s]
# Processing COVID tweets:   1%|▏         | 67/4609 [00:11<12:26,  6.08it/s]
# Processing COVID tweets:   1%|▏         | 68/4609 [00:11<12:12,  6.20it/s]
# Processing COVID tweets:   1%|▏         | 69/4609 [00:11<12:02,  6.28it/s]
# Processing COVID tweets:   2%|▏         | 70/4609 [00:12<12:01,  6.29it/s]
# Processing COVID tweets:   2%|▏         | 71/4609 [00:12<12:00,  6.30it/s]
# Processing COVID tweets:   2%|▏         | 72/4609 [00:12<11:58,  6.31it/s]
# Processing COVID tweets:   2%|▏         | 73/4609 [00:12<11:44,  6.44it/s]
# Processing COVID tweets:   2%|▏         | 74/4609 [00:12<12:00,  6.30it/s]
# Processing COVID tweets:   2%|▏         | 75/4609 [00:12<12:12,  6.19it/s]
# Processing COVID tweets:   2%|▏         | 76/4609 [00:13<12:03,  6.27it/s]
# Processing COVID tweets:   2%|▏         | 77/4609 [00:13<12:02,  6.27it/s]
# Processing COVID tweets:   2%|▏         | 78/4609 [00:13<11:54,  6.34it/s]
# Processing COVID tweets:   2%|▏         | 79/4609 [00:13<11:54,  6.34it/s]
# Processing COVID tweets:   2%|▏         | 80/4609 [00:13<12:04,  6.25it/s]
# Processing COVID tweets:   2%|▏         | 81/4609 [00:13<12:21,  6.11it/s]
# Processing COVID tweets:   2%|▏         | 82/4609 [00:13<11:51,  6.36it/s]
# Processing COVID tweets:   2%|▏         | 83/4609 [00:14<11:41,  6.45it/s]
# Processing COVID tweets:   2%|▏         | 84/4609 [00:14<11:56,  6.32it/s]
# Processing COVID tweets:   2%|▏         | 85/4609 [00:14<12:18,  6.13it/s]
# Processing COVID tweets:   2%|▏         | 86/4609 [00:14<12:27,  6.05it/s]
# Processing COVID tweets:   2%|▏         | 87/4609 [00:14<12:15,  6.15it/s]
# Processing COVID tweets:   2%|▏         | 88/4609 [00:14<12:06,  6.22it/s]
# Processing COVID tweets:   2%|▏         | 89/4609 [00:15<11:50,  6.36it/s]
# Processing COVID tweets:   2%|▏         | 90/4609 [00:15<11:55,  6.32it/s]
# Processing COVID tweets:   2%|▏         | 91/4609 [00:15<12:46,  5.89it/s]
# Processing COVID tweets:   2%|▏         | 92/4609 [00:15<13:10,  5.72it/s]
# Processing COVID tweets:   2%|▏         | 93/4609 [00:15<13:16,  5.67it/s]
# Processing COVID tweets:   2%|▏         | 94/4609 [00:15<12:59,  5.79it/s]
# Processing COVID tweets:   2%|▏         | 95/4609 [00:16<12:15,  6.13it/s]
# Processing COVID tweets:   2%|▏         | 96/4609 [00:16<12:10,  6.18it/s]
# Processing COVID tweets:   2%|▏         | 97/4609 [00:16<11:51,  6.34it/s]
# Processing COVID tweets:   2%|▏         | 98/4609 [00:16<11:39,  6.45it/s]
# Processing COVID tweets:   2%|▏         | 99/4609 [00:16<11:38,  6.46it/s]
# Processing COVID tweets:   2%|▏         | 100/4609 [00:16<11:26,  6.57it/s]
# Processing COVID tweets:   2%|▏         | 101/4609 [00:17<11:18,  6.65it/s]
# Processing COVID tweets:   2%|▏         | 102/4609 [00:17<11:08,  6.74it/s]
# Processing COVID tweets:   2%|▏         | 103/4609 [00:17<11:16,  6.66it/s]
# Processing COVID tweets:   2%|▏         | 104/4609 [00:17<11:20,  6.62it/s]
# Processing COVID tweets:   2%|▏         | 105/4609 [00:17<11:21,  6.61it/s]
# Processing COVID tweets:   2%|▏         | 106/4609 [00:17<11:15,  6.66it/s]
# Processing COVID tweets:   2%|▏         | 107/4609 [00:17<11:09,  6.72it/s]
# Processing COVID tweets:   2%|▏         | 108/4609 [00:18<11:06,  6.76it/s]
# Processing COVID tweets:   2%|▏         | 109/4609 [00:18<11:10,  6.71it/s]
# Processing COVID tweets:   2%|▏         | 110/4609 [00:18<11:14,  6.67it/s]
# Processing COVID tweets:   2%|▏         | 111/4609 [00:18<11:12,  6.69it/s]
# Processing COVID tweets:   2%|▏         | 112/4609 [00:18<11:10,  6.71it/s]
# Processing COVID tweets:   2%|▏         | 113/4609 [00:18<11:07,  6.74it/s]
# Processing COVID tweets:   2%|▏         | 114/4609 [00:18<11:06,  6.75it/s]
# Processing COVID tweets:   2%|▏         | 115/4609 [00:19<10:53,  6.87it/s]
# Processing COVID tweets:   3%|▎         | 116/4609 [00:19<10:56,  6.85it/s]
# Processing COVID tweets:   3%|▎         | 117/4609 [00:19<11:03,  6.77it/s]
# Processing COVID tweets:   3%|▎         | 118/4609 [00:19<11:03,  6.77it/s]
# Processing COVID tweets:   3%|▎         | 119/4609 [00:19<11:10,  6.69it/s]
# Processing COVID tweets:   3%|▎         | 120/4609 [00:19<11:11,  6.69it/s]
# Processing COVID tweets:   3%|▎         | 121/4609 [00:19<11:05,  6.74it/s]
# Processing COVID tweets:   3%|▎         | 122/4609 [00:20<10:57,  6.83it/s]
# Processing COVID tweets:   3%|▎         | 123/4609 [00:20<11:02,  6.77it/s]
# Processing COVID tweets:   3%|▎         | 124/4609 [00:20<11:03,  6.76it/s]
# Processing COVID tweets:   3%|▎         | 125/4609 [00:20<11:07,  6.72it/s]
# Processing COVID tweets:   3%|▎         | 126/4609 [00:20<11:18,  6.61it/s]
# Processing COVID tweets:   3%|▎         | 127/4609 [00:20<11:18,  6.60it/s]
# Processing COVID tweets:   3%|▎         | 128/4609 [00:21<11:19,  6.59it/s]
# Processing COVID tweets:   3%|▎         | 129/4609 [00:21<11:19,  6.59it/s]
# Processing COVID tweets:   3%|▎         | 130/4609 [00:21<11:25,  6.54it/s]
# Processing COVID tweets:   3%|▎         | 131/4609 [00:21<11:26,  6.52it/s]
# Processing COVID tweets:   3%|▎         | 132/4609 [00:21<11:23,  6.55it/s]
# Processing COVID tweets:   3%|▎         | 133/4609 [00:21<11:20,  6.58it/s]
# Processing COVID tweets:   3%|▎         | 134/4609 [00:21<11:18,  6.59it/s]
# Processing COVID tweets:   3%|▎         | 135/4609 [00:22<11:12,  6.65it/s]
# Processing COVID tweets:   3%|▎         | 136/4609 [00:22<11:16,  6.61it/s]
# Processing COVID tweets:   3%|▎         | 137/4609 [00:22<11:15,  6.62it/s]
# Processing COVID tweets:   3%|▎         | 138/4609 [00:22<11:15,  6.62it/s]
# Processing COVID tweets:   3%|▎         | 139/4609 [00:22<11:15,  6.62it/s]
# Processing COVID tweets:   3%|▎         | 140/4609 [00:22<11:12,  6.65it/s]
# Processing COVID tweets:   3%|▎         | 141/4609 [00:22<11:06,  6.71it/s]
# Processing COVID tweets:   3%|▎         | 142/4609 [00:23<11:04,  6.72it/s]
# Processing COVID tweets:   3%|▎         | 143/4609 [00:23<11:06,  6.70it/s]
# Processing COVID tweets:   3%|▎         | 144/4609 [00:23<11:05,  6.70it/s]
# Processing COVID tweets:   3%|▎         | 145/4609 [00:23<11:11,  6.64it/s]
# Processing COVID tweets:   3%|▎         | 146/4609 [00:23<11:22,  6.54it/s]
# Processing COVID tweets:   3%|▎         | 147/4609 [00:23<11:35,  6.42it/s]
# Processing COVID tweets:   3%|▎         | 148/4609 [00:24<11:29,  6.47it/s]
# Processing COVID tweets:   3%|▎         | 149/4609 [00:24<11:30,  6.46it/s]
# Processing COVID tweets:   3%|▎         | 150/4609 [00:24<11:16,  6.59it/s]
# Processing COVID tweets:   3%|▎         | 151/4609 [00:24<11:03,  6.72it/s]
# Processing COVID tweets:   3%|▎         | 152/4609 [00:24<11:04,  6.70it/s]
# Processing COVID tweets:   3%|▎         | 153/4609 [00:24<11:05,  6.70it/s]
# Processing COVID tweets:   3%|▎         | 154/4609 [00:24<11:03,  6.71it/s]
# Processing COVID tweets:   3%|▎         | 155/4609 [00:25<11:00,  6.74it/s]
# Processing COVID tweets:   3%|▎         | 156/4609 [00:25<11:00,  6.74it/s]
# Processing COVID tweets:   3%|▎         | 157/4609 [00:25<11:02,  6.72it/s]
# Processing COVID tweets:   3%|▎         | 158/4609 [00:25<11:00,  6.74it/s]
# Processing COVID tweets:   3%|▎         | 159/4609 [00:25<10:59,  6.75it/s]
# Processing COVID tweets:   3%|▎         | 160/4609 [00:25<10:51,  6.83it/s]
# Processing COVID tweets:   3%|▎         | 161/4609 [00:25<10:53,  6.81it/s]
# Processing COVID tweets:   4%|▎         | 162/4609 [00:26<10:52,  6.81it/s]
# Processing COVID tweets:   4%|▎         | 163/4609 [00:26<10:57,  6.76it/s]
# Processing COVID tweets:   4%|▎         | 164/4609 [00:26<11:03,  6.70it/s]
# Processing COVID tweets:   4%|▎         | 165/4609 [00:26<11:05,  6.68it/s]
# Processing COVID tweets:   4%|▎         | 166/4609 [00:26<11:07,  6.66it/s]
# Processing COVID tweets:   4%|▎         | 167/4609 [00:26<11:10,  6.63it/s]
# Processing COVID tweets:   4%|▎         | 168/4609 [00:27<11:09,  6.63it/s]
# Processing COVID tweets:   4%|▎         | 169/4609 [00:27<11:08,  6.64it/s]
# Processing COVID tweets:   4%|▎         | 170/4609 [00:27<11:05,  6.67it/s]
# Processing COVID tweets:   4%|▎         | 171/4609 [00:27<11:10,  6.62it/s]
# Processing COVID tweets:   4%|▎         | 172/4609 [00:27<11:07,  6.64it/s]
# Processing COVID tweets:   4%|▍         | 173/4609 [00:27<10:57,  6.75it/s]
# Processing COVID tweets:   4%|▍         | 174/4609 [00:27<10:56,  6.76it/s]
# Processing COVID tweets:   4%|▍         | 175/4609 [00:28<10:58,  6.73it/s]
# Processing COVID tweets:   4%|▍         | 176/4609 [00:28<11:02,  6.70it/s]
# Processing COVID tweets:   4%|▍         | 177/4609 [00:28<11:04,  6.67it/s]
# Processing COVID tweets:   4%|▍         | 178/4609 [00:28<10:55,  6.76it/s]
# Processing COVID tweets:   4%|▍         | 179/4609 [00:28<11:03,  6.68it/s]
# Processing COVID tweets:   4%|▍         | 180/4609 [00:28<11:03,  6.67it/s]
# Processing COVID tweets:   4%|▍         | 181/4609 [00:28<11:01,  6.70it/s]
# Processing COVID tweets:   4%|▍         | 182/4609 [00:29<11:02,  6.68it/s]
# Processing COVID tweets:   4%|▍         | 183/4609 [00:29<10:56,  6.74it/s]
# Processing COVID tweets:   4%|▍         | 184/4609 [00:29<10:53,  6.77it/s]
# Processing COVID tweets:   4%|▍         | 185/4609 [00:29<10:57,  6.73it/s]
# Processing COVID tweets:   4%|▍         | 186/4609 [00:29<10:57,  6.72it/s]
# Processing COVID tweets:   4%|▍         | 187/4609 [00:29<10:55,  6.75it/s]
# Processing COVID tweets:   4%|▍         | 188/4609 [00:30<10:54,  6.75it/s]
# Processing COVID tweets:   4%|▍         | 189/4609 [00:30<10:58,  6.72it/s]
# Processing COVID tweets:   4%|▍         | 190/4609 [00:30<10:59,  6.70it/s]
# Processing COVID tweets:   4%|▍         | 191/4609 [00:30<10:58,  6.71it/s]
# Processing COVID tweets:   4%|▍         | 192/4609 [00:30<10:53,  6.76it/s]
# Processing COVID tweets:   4%|▍         | 193/4609 [00:30<10:54,  6.75it/s]
# Processing COVID tweets:   4%|▍         | 194/4609 [00:30<10:53,  6.76it/s]
# Processing COVID tweets:   4%|▍         | 195/4609 [00:31<10:52,  6.77it/s]
# Processing COVID tweets:   4%|▍         | 196/4609 [00:31<10:53,  6.75it/s]
# Processing COVID tweets:   4%|▍         | 197/4609 [00:31<11:02,  6.65it/s]
# Processing COVID tweets:   4%|▍         | 198/4609 [00:31<11:07,  6.61it/s]
# Processing COVID tweets:   4%|▍         | 199/4609 [00:31<11:09,  6.59it/s]
# Processing COVID tweets:   4%|▍         | 200/4609 [00:31<11:09,  6.59it/s]
# Processing COVID tweets:   4%|▍         | 201/4609 [00:31<11:04,  6.64it/s]
# Processing COVID tweets:   4%|▍         | 202/4609 [00:32<11:01,  6.66it/s]
# Processing COVID tweets:   4%|▍         | 203/4609 [00:32<11:04,  6.63it/s]
# Processing COVID tweets:   4%|▍         | 204/4609 [00:32<11:17,  6.50it/s]
# Processing COVID tweets:   4%|▍         | 205/4609 [00:32<11:15,  6.52it/s]
# Processing COVID tweets:   4%|▍         | 206/4609 [00:32<11:12,  6.54it/s]
# Processing COVID tweets:   4%|▍         | 207/4609 [00:32<11:08,  6.59it/s]
# Processing COVID tweets:   5%|▍         | 208/4609 [00:33<11:04,  6.62it/s]
# Processing COVID tweets:   5%|▍         | 209/4609 [00:33<11:02,  6.64it/s]
# Processing COVID tweets:   5%|▍         | 210/4609 [00:33<11:09,  6.57it/s]
# Processing COVID tweets:   5%|▍         | 211/4609 [00:33<11:04,  6.62it/s]
# Processing COVID tweets:   5%|▍         | 212/4609 [00:33<11:16,  6.50it/s]
# Processing COVID tweets:   5%|▍         | 213/4609 [00:33<11:42,  6.26it/s]
# Processing COVID tweets:   5%|▍         | 214/4609 [00:33<11:27,  6.40it/s]
# Processing COVID tweets:   5%|▍         | 215/4609 [00:34<11:18,  6.48it/s]
# Processing COVID tweets:   5%|▍         | 216/4609 [00:34<11:25,  6.41it/s]
# Processing COVID tweets:   5%|▍         | 217/4609 [00:34<11:21,  6.44it/s]
# Processing COVID tweets:   5%|▍         | 218/4609 [00:34<11:16,  6.49it/s]
# Processing COVID tweets:   5%|▍         | 219/4609 [00:34<11:14,  6.51it/s]
# Processing COVID tweets:   5%|▍         | 220/4609 [00:34<11:08,  6.56it/s]
# Processing COVID tweets:   5%|▍         | 221/4609 [00:35<11:03,  6.61it/s]
# Processing COVID tweets:   5%|▍         | 222/4609 [00:35<10:56,  6.68it/s]
# Processing COVID tweets:   5%|▍         | 223/4609 [00:35<10:54,  6.70it/s]
# Processing COVID tweets:   5%|▍         | 224/4609 [00:35<11:00,  6.64it/s]
# Processing COVID tweets:   5%|▍         | 225/4609 [00:35<11:02,  6.62it/s]
# Processing COVID tweets:   5%|▍         | 226/4609 [00:35<10:59,  6.65it/s]
# Processing COVID tweets:   5%|▍         | 227/4609 [00:35<11:00,  6.63it/s]
# Processing COVID tweets:   5%|▍         | 228/4609 [00:36<10:59,  6.64it/s]
# Processing COVID tweets:   5%|▍         | 229/4609 [00:36<10:59,  6.64it/s]
# Processing COVID tweets:   5%|▍         | 230/4609 [00:36<10:58,  6.65it/s]
# Processing COVID tweets:   5%|▌         | 231/4609 [00:36<10:54,  6.69it/s]
# Processing COVID tweets:   5%|▌         | 232/4609 [00:36<10:54,  6.69it/s]
# Processing COVID tweets:   5%|▌         | 233/4609 [00:36<10:59,  6.64it/s]
# Processing COVID tweets:   5%|▌         | 234/4609 [00:36<11:01,  6.61it/s]
# Processing COVID tweets:   5%|▌         | 235/4609 [00:37<11:01,  6.61it/s]
# Processing COVID tweets:   5%|▌         | 236/4609 [00:37<11:03,  6.60it/s]
# Processing COVID tweets:   5%|▌         | 237/4609 [00:37<11:02,  6.60it/s]
# Processing COVID tweets:   5%|▌         | 238/4609 [00:37<11:04,  6.58it/s]
# Processing COVID tweets:   5%|▌         | 239/4609 [00:37<11:04,  6.58it/s]
# Processing COVID tweets:   5%|▌         | 240/4609 [00:37<10:59,  6.62it/s]
# Processing COVID tweets:   5%|▌         | 241/4609 [00:38<10:49,  6.73it/s]
# Processing COVID tweets:   5%|▌         | 242/4609 [00:38<10:57,  6.64it/s]
# Processing COVID tweets:   5%|▌         | 243/4609 [00:38<10:53,  6.68it/s]
# Processing COVID tweets:   5%|▌         | 244/4609 [00:38<11:00,  6.61it/s]
# Processing COVID tweets:   5%|▌         | 245/4609 [00:38<11:02,  6.59it/s]
# Processing COVID tweets:   5%|▌         | 246/4609 [00:38<11:02,  6.59it/s]
# Processing COVID tweets:   5%|▌         | 247/4609 [00:38<11:00,  6.61it/s]
# Processing COVID tweets:   5%|▌         | 248/4609 [00:39<10:56,  6.64it/s]
# Processing COVID tweets:   5%|▌         | 249/4609 [00:39<10:53,  6.67it/s]
# Processing COVID tweets:   5%|▌         | 250/4609 [00:39<10:57,  6.63it/s]
# Processing COVID tweets:   5%|▌         | 251/4609 [00:39<10:56,  6.64it/s]
# Processing COVID tweets:   5%|▌         | 252/4609 [00:39<11:00,  6.60it/s]
# Processing COVID tweets:   5%|▌         | 253/4609 [00:39<11:12,  6.48it/s]
# Processing COVID tweets:   6%|▌         | 254/4609 [00:40<11:07,  6.53it/s]
# Processing COVID tweets:   6%|▌         | 255/4609 [00:40<10:54,  6.65it/s]
# Processing COVID tweets:   6%|▌         | 256/4609 [00:40<10:58,  6.61it/s]
# Processing COVID tweets:   6%|▌         | 257/4609 [00:40<11:14,  6.45it/s]
# Processing COVID tweets:   6%|▌         | 258/4609 [00:40<11:08,  6.51it/s]
# Processing COVID tweets:   6%|▌         | 259/4609 [00:40<10:51,  6.67it/s]
# Processing COVID tweets:   6%|▌         | 260/4609 [00:40<10:46,  6.73it/s]
# Processing COVID tweets:   6%|▌         | 261/4609 [00:41<10:54,  6.64it/s]
# Processing COVID tweets:   6%|▌         | 262/4609 [00:41<10:54,  6.64it/s]
# Processing COVID tweets:   6%|▌         | 263/4609 [00:41<10:49,  6.69it/s]
# Processing COVID tweets:   6%|▌         | 264/4609 [00:41<10:50,  6.68it/s]
# Processing COVID tweets:   6%|▌         | 265/4609 [00:41<10:54,  6.64it/s]
# Processing COVID tweets:   6%|▌         | 266/4609 [00:41<10:53,  6.64it/s]
# Processing COVID tweets:   6%|▌         | 267/4609 [00:41<10:45,  6.73it/s]
# Processing COVID tweets:   6%|▌         | 268/4609 [00:42<10:45,  6.72it/s]
# Processing COVID tweets:   6%|▌         | 269/4609 [00:42<10:44,  6.73it/s]
# Processing COVID tweets:   6%|▌         | 270/4609 [00:42<10:47,  6.70it/s]
# Processing COVID tweets:   6%|▌         | 271/4609 [00:42<10:42,  6.75it/s]
# Processing COVID tweets:   6%|▌         | 272/4609 [00:42<10:42,  6.76it/s]
# Processing COVID tweets:   6%|▌         | 273/4609 [00:42<10:44,  6.73it/s]
# Processing COVID tweets:   6%|▌         | 274/4609 [00:43<10:43,  6.73it/s]
# Processing COVID tweets:   6%|▌         | 275/4609 [00:43<10:36,  6.81it/s]
# Processing COVID tweets:   6%|▌         | 276/4609 [00:43<10:43,  6.73it/s]
# Processing COVID tweets:   6%|▌         | 277/4609 [00:43<10:40,  6.77it/s]
# Processing COVID tweets:   6%|▌         | 278/4609 [00:43<10:59,  6.57it/s]
# Processing COVID tweets:   6%|▌         | 279/4609 [00:43<11:18,  6.38it/s]
# Processing COVID tweets:   6%|▌         | 280/4609 [00:43<11:18,  6.38it/s]
# Processing COVID tweets:   6%|▌         | 281/4609 [00:44<11:08,  6.48it/s]
# Processing COVID tweets:   6%|▌         | 282/4609 [00:44<11:02,  6.53it/s]
# Processing COVID tweets:   6%|▌         | 283/4609 [00:44<11:01,  6.54it/s]
# Processing COVID tweets:   6%|▌         | 284/4609 [00:44<11:02,  6.53it/s]
# Processing COVID tweets:   6%|▌         | 285/4609 [00:44<11:12,  6.43it/s]
# Processing COVID tweets:   6%|▌         | 286/4609 [00:44<11:03,  6.51it/s]
# Processing COVID tweets:   6%|▌         | 287/4609 [00:44<10:57,  6.57it/s]
# Processing COVID tweets:   6%|▌         | 288/4609 [00:45<10:47,  6.68it/s]
# Processing COVID tweets:   6%|▋         | 289/4609 [00:45<10:48,  6.66it/s]
# Processing COVID tweets:   6%|▋         | 290/4609 [00:45<10:48,  6.66it/s]
# Processing COVID tweets:   6%|▋         | 291/4609 [00:45<10:41,  6.73it/s]
# Processing COVID tweets:   6%|▋         | 292/4609 [00:45<10:45,  6.69it/s]
# Processing COVID tweets:   6%|▋         | 293/4609 [00:45<10:29,  6.86it/s]
# Processing COVID tweets:   6%|▋         | 294/4609 [00:46<10:23,  6.92it/s]
# Processing COVID tweets:   6%|▋         | 295/4609 [00:46<10:22,  6.93it/s]
# Processing COVID tweets:   6%|▋         | 296/4609 [00:46<10:25,  6.89it/s]
# Processing COVID tweets:   6%|▋         | 297/4609 [00:46<10:28,  6.86it/s]
# Processing COVID tweets:   6%|▋         | 298/4609 [00:46<10:25,  6.89it/s]
# Processing COVID tweets:   6%|▋         | 299/4609 [00:46<10:51,  6.62it/s]
# Processing COVID tweets:   7%|▋         | 300/4609 [00:46<10:52,  6.61it/s]
# Processing COVID tweets:   7%|▋         | 301/4609 [00:47<11:18,  6.35it/s]
# Processing COVID tweets:   7%|▋         | 302/4609 [00:47<11:28,  6.26it/s]
# Processing COVID tweets:   7%|▋         | 303/4609 [00:47<11:07,  6.45it/s]
# Processing COVID tweets:   7%|▋         | 304/4609 [00:47<11:01,  6.51it/s]
# Processing COVID tweets:   7%|▋         | 305/4609 [00:47<11:08,  6.44it/s]
# Processing COVID tweets:   7%|▋         | 306/4609 [00:47<11:23,  6.29it/s]
# Processing COVID tweets:   7%|▋         | 307/4609 [00:48<11:16,  6.36it/s]
# Processing COVID tweets:   7%|▋         | 308/4609 [00:48<11:09,  6.42it/s]
# Processing COVID tweets:   7%|▋         | 309/4609 [00:48<10:57,  6.54it/s]
# Processing COVID tweets:   7%|▋         | 310/4609 [00:48<10:51,  6.60it/s]
# Processing COVID tweets:   7%|▋         | 311/4609 [00:48<10:51,  6.60it/s]
# Processing COVID tweets:   7%|▋         | 312/4609 [00:48<10:50,  6.61it/s]
# Processing COVID tweets:   7%|▋         | 313/4609 [00:48<10:50,  6.61it/s]
# Processing COVID tweets:   7%|▋         | 314/4609 [00:49<10:38,  6.73it/s]
# Processing COVID tweets:   7%|▋         | 315/4609 [00:49<10:40,  6.71it/s]
# Processing COVID tweets:   7%|▋         | 316/4609 [00:49<10:36,  6.74it/s]
# Processing COVID tweets:   7%|▋         | 317/4609 [00:49<10:35,  6.76it/s]
# Processing COVID tweets:   7%|▋         | 318/4609 [00:49<10:54,  6.56it/s]
# Processing COVID tweets:   7%|▋         | 319/4609 [00:49<10:43,  6.67it/s]
# Processing COVID tweets:   7%|▋         | 320/4609 [00:49<10:39,  6.70it/s]
# Processing COVID tweets:   7%|▋         | 321/4609 [00:50<10:38,  6.72it/s]
# Processing COVID tweets:   7%|▋         | 322/4609 [00:50<10:39,  6.70it/s]
# Processing COVID tweets:   7%|▋         | 323/4609 [00:50<10:43,  6.67it/s]
# Processing COVID tweets:   7%|▋         | 324/4609 [00:50<10:43,  6.66it/s]
# Processing COVID tweets:   7%|▋         | 325/4609 [00:50<10:46,  6.63it/s]
# Processing COVID tweets:   7%|▋         | 326/4609 [00:50<10:51,  6.58it/s]
# Processing COVID tweets:   7%|▋         | 327/4609 [00:51<10:50,  6.59it/s]
# Processing COVID tweets:   7%|▋         | 328/4609 [00:51<10:35,  6.74it/s]
# Processing COVID tweets:   7%|▋         | 329/4609 [00:51<10:35,  6.73it/s]
# Processing COVID tweets:   7%|▋         | 330/4609 [00:51<10:42,  6.66it/s]
# Processing COVID tweets:   7%|▋         | 331/4609 [00:51<10:31,  6.78it/s]
# Processing COVID tweets:   7%|▋         | 332/4609 [00:51<10:34,  6.74it/s]
# Processing COVID tweets:   7%|▋         | 333/4609 [00:51<10:41,  6.67it/s]
# Processing COVID tweets:   7%|▋         | 334/4609 [00:52<10:27,  6.82it/s]
# Processing COVID tweets:   7%|▋         | 335/4609 [00:52<10:29,  6.79it/s]
# Processing COVID tweets:   7%|▋         | 336/4609 [00:52<10:37,  6.71it/s]
# Processing COVID tweets:   7%|▋         | 337/4609 [00:52<10:37,  6.70it/s]
# Processing COVID tweets:   7%|▋         | 338/4609 [00:52<10:41,  6.66it/s]
# Processing COVID tweets:   7%|▋         | 339/4609 [00:52<10:35,  6.72it/s]
# Processing COVID tweets:   7%|▋         | 340/4609 [00:52<10:32,  6.75it/s]
# Processing COVID tweets:   7%|▋         | 341/4609 [00:53<10:28,  6.79it/s]
# Processing COVID tweets:   7%|▋         | 342/4609 [00:53<10:33,  6.74it/s]
# Processing COVID tweets:   7%|▋         | 343/4609 [00:53<10:31,  6.75it/s]
# Processing COVID tweets:   7%|▋         | 344/4609 [00:53<10:29,  6.77it/s]
# Processing COVID tweets:   7%|▋         | 345/4609 [00:53<10:50,  6.56it/s]
# Processing COVID tweets:   8%|▊         | 346/4609 [00:53<11:13,  6.33it/s]
# Processing COVID tweets:   8%|▊         | 347/4609 [00:54<10:59,  6.47it/s]
# Processing COVID tweets:   8%|▊         | 348/4609 [00:54<10:43,  6.62it/s]
# Processing COVID tweets:   8%|▊         | 349/4609 [00:54<10:41,  6.64it/s]
# Processing COVID tweets:   8%|▊         | 350/4609 [00:54<10:36,  6.69it/s]
# Processing COVID tweets:   8%|▊         | 351/4609 [00:54<10:36,  6.69it/s]
# Processing COVID tweets:   8%|▊         | 352/4609 [00:54<10:46,  6.58it/s]
# Processing COVID tweets:   8%|▊         | 353/4609 [00:54<11:06,  6.39it/s]
# Processing COVID tweets:   8%|▊         | 354/4609 [00:55<11:08,  6.36it/s]
# Processing COVID tweets:   8%|▊         | 355/4609 [00:55<10:59,  6.45it/s]
# Processing COVID tweets:   8%|▊         | 356/4609 [00:55<10:51,  6.52it/s]
# Processing COVID tweets:   8%|▊         | 357/4609 [00:55<10:44,  6.60it/s]
# Processing COVID tweets:   8%|▊         | 358/4609 [00:55<10:41,  6.63it/s]
# Processing COVID tweets:   8%|▊         | 359/4609 [00:55<10:36,  6.68it/s]
# Processing COVID tweets:   8%|▊         | 360/4609 [00:55<10:33,  6.71it/s]
# Processing COVID tweets:   8%|▊         | 361/4609 [00:56<10:30,  6.73it/s]
# Processing COVID tweets:   8%|▊         | 362/4609 [00:56<10:27,  6.77it/s]
# Processing COVID tweets:   8%|▊         | 363/4609 [00:56<10:27,  6.77it/s]
# Processing COVID tweets:   8%|▊         | 364/4609 [00:56<10:30,  6.74it/s]
# Processing COVID tweets:   8%|▊         | 365/4609 [00:56<10:38,  6.65it/s]
# Processing COVID tweets:   8%|▊         | 366/4609 [00:56<10:34,  6.69it/s]
# Processing COVID tweets:   8%|▊         | 367/4609 [00:57<10:33,  6.70it/s]
# Processing COVID tweets:   8%|▊         | 368/4609 [00:57<10:29,  6.74it/s]
# Processing COVID tweets:   8%|▊         | 369/4609 [00:57<10:33,  6.70it/s]
# Processing COVID tweets:   8%|▊         | 370/4609 [00:57<10:36,  6.66it/s]
# Processing COVID tweets:   8%|▊         | 371/4609 [00:57<10:38,  6.63it/s]
# Processing COVID tweets:   8%|▊         | 372/4609 [00:57<10:38,  6.64it/s]
# Processing COVID tweets:   8%|▊         | 373/4609 [00:57<10:34,  6.68it/s]
# Processing COVID tweets:   8%|▊         | 374/4609 [00:58<10:33,  6.69it/s]
# Processing COVID tweets:   8%|▊         | 375/4609 [00:58<10:33,  6.68it/s]
# Processing COVID tweets:   8%|▊         | 376/4609 [00:58<10:31,  6.70it/s]
# Processing COVID tweets:   8%|▊         | 377/4609 [00:58<10:38,  6.62it/s]
# Processing COVID tweets:   8%|▊         | 378/4609 [00:58<10:43,  6.58it/s]
# Processing COVID tweets:   8%|▊         | 379/4609 [00:58<10:40,  6.61it/s]
# Processing COVID tweets:   8%|▊         | 380/4609 [00:58<10:36,  6.65it/s]
# Processing COVID tweets:   8%|▊         | 381/4609 [00:59<10:28,  6.73it/s]
# Processing COVID tweets:   8%|▊         | 382/4609 [00:59<10:28,  6.73it/s]
# Processing COVID tweets:   8%|▊         | 383/4609 [00:59<10:36,  6.64it/s]
# Processing COVID tweets:   8%|▊         | 384/4609 [00:59<10:45,  6.54it/s]
# Processing COVID tweets:   8%|▊         | 385/4609 [00:59<10:40,  6.60it/s]
# Processing COVID tweets:   8%|▊         | 386/4609 [00:59<10:34,  6.66it/s]
# Processing COVID tweets:   8%|▊         | 387/4609 [01:00<10:28,  6.72it/s]
# Processing COVID tweets:   8%|▊         | 388/4609 [01:00<10:21,  6.79it/s]
# Processing COVID tweets:   8%|▊         | 389/4609 [01:00<10:21,  6.79it/s]
# Processing COVID tweets:   8%|▊         | 390/4609 [01:00<10:22,  6.78it/s]
# Processing COVID tweets:   8%|▊         | 391/4609 [01:00<10:14,  6.86it/s]
# Processing COVID tweets:   9%|▊         | 392/4609 [01:00<10:21,  6.79it/s]
# Processing COVID tweets:   9%|▊         | 393/4609 [01:00<10:12,  6.88it/s]
# Processing COVID tweets:   9%|▊         | 394/4609 [01:01<10:16,  6.84it/s]
# Processing COVID tweets:   9%|▊         | 395/4609 [01:01<10:19,  6.80it/s]
# Processing COVID tweets:   9%|▊         | 396/4609 [01:01<10:19,  6.80it/s]
# Processing COVID tweets:   9%|▊         | 397/4609 [01:01<10:23,  6.76it/s]
# Processing COVID tweets:   9%|▊         | 398/4609 [01:01<10:26,  6.72it/s]
# Processing COVID tweets:   9%|▊         | 399/4609 [01:01<10:22,  6.76it/s]
# Processing COVID tweets:   9%|▊         | 400/4609 [01:01<10:24,  6.74it/s]
# Processing COVID tweets:   9%|▊         | 401/4609 [01:02<10:24,  6.74it/s]
# Processing COVID tweets:   9%|▊         | 402/4609 [01:02<10:25,  6.73it/s]
# Processing COVID tweets:   9%|▊         | 403/4609 [01:02<10:27,  6.71it/s]
# Processing COVID tweets:   9%|▉         | 404/4609 [01:02<10:28,  6.70it/s]
# Processing COVID tweets:   9%|▉         | 405/4609 [01:02<10:39,  6.57it/s]
# Processing COVID tweets:   9%|▉         | 406/4609 [01:02<10:36,  6.60it/s]
# Processing COVID tweets:   9%|▉         | 407/4609 [01:03<10:33,  6.64it/s]
# Processing COVID tweets:   9%|▉         | 408/4609 [01:03<10:30,  6.66it/s]
# Processing COVID tweets:   9%|▉         | 409/4609 [01:03<10:28,  6.68it/s]
# Processing COVID tweets:   9%|▉         | 410/4609 [01:03<10:24,  6.72it/s]
# Processing COVID tweets:   9%|▉         | 411/4609 [01:03<10:33,  6.63it/s]
# Processing COVID tweets:   9%|▉         | 412/4609 [01:03<10:38,  6.57it/s]
# Processing COVID tweets:   9%|▉         | 413/4609 [01:03<10:50,  6.45it/s]
# Processing COVID tweets:   9%|▉         | 414/4609 [01:04<10:45,  6.50it/s]
# Processing COVID tweets:   9%|▉         | 415/4609 [01:04<10:38,  6.57it/s]
# Processing COVID tweets:   9%|▉         | 416/4609 [01:04<10:39,  6.56it/s]
# Processing COVID tweets:   9%|▉         | 417/4609 [01:04<10:39,  6.55it/s]
# Processing COVID tweets:   9%|▉         | 418/4609 [01:04<10:39,  6.56it/s]
# Processing COVID tweets:   9%|▉         | 419/4609 [01:04<10:22,  6.73it/s]
# Processing COVID tweets:   9%|▉         | 420/4609 [01:04<10:19,  6.77it/s]
# Processing COVID tweets:   9%|▉         | 421/4609 [01:05<10:21,  6.74it/s]
# Processing COVID tweets:   9%|▉         | 422/4609 [01:05<10:22,  6.72it/s]
# Processing COVID tweets:   9%|▉         | 423/4609 [01:05<10:23,  6.71it/s]
# Processing COVID tweets:   9%|▉         | 424/4609 [01:05<10:22,  6.72it/s]
# Processing COVID tweets:   9%|▉         | 425/4609 [01:05<10:16,  6.79it/s]
# Processing COVID tweets:   9%|▉         | 426/4609 [01:05<10:06,  6.90it/s]
# Processing COVID tweets:   9%|▉         | 427/4609 [01:05<10:06,  6.89it/s]
# Processing COVID tweets:   9%|▉         | 428/4609 [01:06<10:08,  6.87it/s]
# Processing COVID tweets:   9%|▉         | 429/4609 [01:06<10:04,  6.91it/s]
# Processing COVID tweets:   9%|▉         | 430/4609 [01:06<10:08,  6.87it/s]
# Processing COVID tweets:   9%|▉         | 431/4609 [01:06<10:09,  6.85it/s]
# Processing COVID tweets:   9%|▉         | 432/4609 [01:06<10:09,  6.85it/s]
# Processing COVID tweets:   9%|▉         | 433/4609 [01:06<10:10,  6.84it/s]
# Processing COVID tweets:   9%|▉         | 434/4609 [01:07<10:14,  6.79it/s]
# Processing COVID tweets:   9%|▉         | 435/4609 [01:07<10:14,  6.79it/s]
# Processing COVID tweets:   9%|▉         | 436/4609 [01:07<10:18,  6.74it/s]
# Processing COVID tweets:   9%|▉         | 437/4609 [01:07<10:09,  6.84it/s]
# Processing COVID tweets:  10%|▉         | 438/4609 [01:07<10:11,  6.82it/s]
# Processing COVID tweets:  10%|▉         | 439/4609 [01:07<10:16,  6.76it/s]
# Processing COVID tweets:  10%|▉         | 440/4609 [01:07<10:26,  6.66it/s]
# Processing COVID tweets:  10%|▉         | 441/4609 [01:08<10:30,  6.61it/s]
# Processing COVID tweets:  10%|▉         | 442/4609 [01:08<10:41,  6.49it/s]
# Processing COVID tweets:  10%|▉         | 443/4609 [01:08<10:39,  6.52it/s]
# Processing COVID tweets:  10%|▉         | 444/4609 [01:08<10:38,  6.52it/s]
# Processing COVID tweets:  10%|▉         | 445/4609 [01:08<10:38,  6.52it/s]
# Processing COVID tweets:  10%|▉         | 446/4609 [01:08<10:38,  6.52it/s]
# Processing COVID tweets:  10%|▉         | 447/4609 [01:08<10:30,  6.60it/s]
# Processing COVID tweets:  10%|▉         | 448/4609 [01:09<10:17,  6.74it/s]
# Processing COVID tweets:  10%|▉         | 449/4609 [01:09<10:12,  6.80it/s]
# Processing COVID tweets:  10%|▉         | 450/4609 [01:09<10:12,  6.79it/s]
# Processing COVID tweets:  10%|▉         | 451/4609 [01:09<10:11,  6.80it/s]
# Processing COVID tweets:  10%|▉         | 452/4609 [01:09<10:10,  6.81it/s]
# Processing COVID tweets:  10%|▉         | 453/4609 [01:09<10:04,  6.88it/s]
# Processing COVID tweets:  10%|▉         | 454/4609 [01:09<10:03,  6.88it/s]
# Processing COVID tweets:  10%|▉         | 455/4609 [01:10<10:08,  6.83it/s]
# Processing COVID tweets:  10%|▉         | 456/4609 [01:10<10:11,  6.79it/s]
# Processing COVID tweets:  10%|▉         | 457/4609 [01:10<10:19,  6.70it/s]
# Processing COVID tweets:  10%|▉         | 458/4609 [01:10<10:14,  6.76it/s]
# Processing COVID tweets:  10%|▉         | 459/4609 [01:10<10:17,  6.72it/s]
# Processing COVID tweets:  10%|▉         | 460/4609 [01:10<10:18,  6.71it/s]
# Processing COVID tweets:  10%|█         | 461/4609 [01:11<10:14,  6.75it/s]
# Processing COVID tweets:  10%|█         | 462/4609 [01:11<10:11,  6.78it/s]
# Processing COVID tweets:  10%|█         | 463/4609 [01:11<10:13,  6.76it/s]
# Processing COVID tweets:  10%|█         | 464/4609 [01:11<10:17,  6.71it/s]
# Processing COVID tweets:  10%|█         | 465/4609 [01:11<10:20,  6.68it/s]
# Processing COVID tweets:  10%|█         | 466/4609 [01:11<10:15,  6.73it/s]
# Processing COVID tweets:  10%|█         | 467/4609 [01:11<10:14,  6.75it/s]
# Processing COVID tweets:  10%|█         | 468/4609 [01:12<10:11,  6.77it/s]
# Processing COVID tweets:  10%|█         | 469/4609 [01:12<10:11,  6.78it/s]
# Processing COVID tweets:  10%|█         | 470/4609 [01:12<10:03,  6.85it/s]
# Processing COVID tweets:  10%|█         | 471/4609 [01:12<10:07,  6.81it/s]
# Processing COVID tweets:  10%|█         | 472/4609 [01:12<10:10,  6.78it/s]
# Processing COVID tweets:  10%|█         | 473/4609 [01:12<10:08,  6.80it/s]
# Processing COVID tweets:  10%|█         | 474/4609 [01:12<10:07,  6.81it/s]
# Processing COVID tweets:  10%|█         | 475/4609 [01:13<10:06,  6.81it/s]
# Processing COVID tweets:  10%|█         | 476/4609 [01:13<10:12,  6.75it/s]
# Processing COVID tweets:  10%|█         | 477/4609 [01:13<10:15,  6.72it/s]
# Processing COVID tweets:  10%|█         | 478/4609 [01:13<10:19,  6.67it/s]
# Processing COVID tweets:  10%|█         | 479/4609 [01:13<10:15,  6.71it/s]
# Processing COVID tweets:  10%|█         | 480/4609 [01:13<10:43,  6.42it/s]
# Processing COVID tweets:  10%|█         | 481/4609 [01:14<10:27,  6.58it/s]
# Processing COVID tweets:  10%|█         | 482/4609 [01:14<10:24,  6.61it/s]
# Processing COVID tweets:  10%|█         | 483/4609 [01:14<10:18,  6.67it/s]
# Processing COVID tweets:  11%|█         | 484/4609 [01:14<10:17,  6.68it/s]
# Processing COVID tweets:  11%|█         | 485/4609 [01:14<10:12,  6.73it/s]
# Processing COVID tweets:  11%|█         | 486/4609 [01:14<10:10,  6.76it/s]
# Processing COVID tweets:  11%|█         | 487/4609 [01:14<10:12,  6.73it/s]
# Processing COVID tweets:  11%|█         | 488/4609 [01:15<10:06,  6.80it/s]
# Processing COVID tweets:  11%|█         | 489/4609 [01:15<10:07,  6.78it/s]
# Processing COVID tweets:  11%|█         | 490/4609 [01:15<10:09,  6.75it/s]
# Processing COVID tweets:  11%|█         | 491/4609 [01:15<10:20,  6.64it/s]
# Processing COVID tweets:  11%|█         | 492/4609 [01:15<10:23,  6.60it/s]
# Processing COVID tweets:  11%|█         | 493/4609 [01:15<10:23,  6.60it/s]
# Processing COVID tweets:  11%|█         | 494/4609 [01:15<10:21,  6.62it/s]
# Processing COVID tweets:  11%|█         | 495/4609 [01:16<10:20,  6.63it/s]
# Processing COVID tweets:  11%|█         | 496/4609 [01:16<10:11,  6.73it/s]
# Processing COVID tweets:  11%|█         | 497/4609 [01:16<10:13,  6.70it/s]
# Processing COVID tweets:  11%|█         | 498/4609 [01:16<10:11,  6.72it/s]
# Processing COVID tweets:  11%|█         | 499/4609 [01:16<10:16,  6.67it/s]
# Processing COVID tweets:  11%|█         | 500/4609 [01:16<10:10,  6.73it/s]
# Processing COVID tweets:  11%|█         | 501/4609 [01:16<10:09,  6.74it/s]
# Processing COVID tweets:  11%|█         | 502/4609 [01:17<10:10,  6.73it/s]
# Processing COVID tweets:  11%|█         | 503/4609 [01:17<10:11,  6.72it/s]
# Processing COVID tweets:  11%|█         | 504/4609 [01:17<10:17,  6.65it/s]
# Processing COVID tweets:  11%|█         | 505/4609 [01:17<10:11,  6.72it/s]
# Processing COVID tweets:  11%|█         | 506/4609 [01:17<10:16,  6.66it/s]
# Processing COVID tweets:  11%|█         | 507/4609 [01:17<10:02,  6.80it/s]
# Processing COVID tweets:  11%|█         | 508/4609 [01:18<10:08,  6.74it/s]
# Processing COVID tweets:  11%|█         | 509/4609 [01:18<10:55,  6.25it/s]
# Processing COVID tweets:  11%|█         | 510/4609 [01:18<10:48,  6.32it/s]
# Processing COVID tweets:  11%|█         | 511/4609 [01:18<11:05,  6.16it/s]
# Processing COVID tweets:  11%|█         | 512/4609 [01:18<11:01,  6.19it/s]
# Processing COVID tweets:  11%|█         | 513/4609 [01:18<11:04,  6.17it/s]
# Processing COVID tweets:  11%|█         | 514/4609 [01:19<10:54,  6.26it/s]
# Processing COVID tweets:  11%|█         | 515/4609 [01:19<10:47,  6.32it/s]
# Processing COVID tweets:  11%|█         | 516/4609 [01:19<10:40,  6.39it/s]
# Processing COVID tweets:  11%|█         | 517/4609 [01:19<10:38,  6.41it/s]
# Processing COVID tweets:  11%|█         | 518/4609 [01:19<10:34,  6.45it/s]
# Processing COVID tweets:  11%|█▏        | 519/4609 [01:19<10:33,  6.46it/s]
# Processing COVID tweets:  11%|█▏        | 520/4609 [01:19<10:22,  6.57it/s]
# Processing COVID tweets:  11%|█▏        | 521/4609 [01:20<10:14,  6.65it/s]
# Processing COVID tweets:  11%|█▏        | 522/4609 [01:20<10:13,  6.66it/s]
# Processing COVID tweets:  11%|█▏        | 523/4609 [01:20<10:15,  6.64it/s]
# Processing COVID tweets:  11%|█▏        | 524/4609 [01:20<10:14,  6.65it/s]
# Processing COVID tweets:  11%|█▏        | 525/4609 [01:20<10:15,  6.64it/s]
# Processing COVID tweets:  11%|█▏        | 526/4609 [01:20<10:20,  6.58it/s]
# Processing COVID tweets:  11%|█▏        | 527/4609 [01:20<10:16,  6.62it/s]
# Processing COVID tweets:  11%|█▏        | 528/4609 [01:21<10:20,  6.58it/s]
# Processing COVID tweets:  11%|█▏        | 529/4609 [01:21<10:17,  6.60it/s]
# Processing COVID tweets:  11%|█▏        | 530/4609 [01:21<10:19,  6.59it/s]
# Processing COVID tweets:  12%|█▏        | 531/4609 [01:21<10:12,  6.66it/s]
# Processing COVID tweets:  12%|█▏        | 532/4609 [01:21<10:14,  6.64it/s]
# Processing COVID tweets:  12%|█▏        | 533/4609 [01:21<10:08,  6.70it/s]
# Processing COVID tweets:  12%|█▏        | 534/4609 [01:22<10:08,  6.69it/s]
# Processing COVID tweets:  12%|█▏        | 535/4609 [01:22<10:07,  6.70it/s]
# Processing COVID tweets:  12%|█▏        | 536/4609 [01:22<10:10,  6.67it/s]
# Processing COVID tweets:  12%|█▏        | 537/4609 [01:22<10:09,  6.68it/s]
# Processing COVID tweets:  12%|█▏        | 538/4609 [01:22<10:12,  6.65it/s]
# Processing COVID tweets:  12%|█▏        | 539/4609 [01:22<10:15,  6.62it/s]
# Processing COVID tweets:  12%|█▏        | 540/4609 [01:22<10:15,  6.62it/s]
# Processing COVID tweets:  12%|█▏        | 541/4609 [01:23<10:14,  6.63it/s]
# Processing COVID tweets:  12%|█▏        | 542/4609 [01:23<10:13,  6.63it/s]
# Processing COVID tweets:  12%|█▏        | 543/4609 [01:23<10:16,  6.60it/s]
# Processing COVID tweets:  12%|█▏        | 544/4609 [01:23<10:22,  6.53it/s]
# Processing COVID tweets:  12%|█▏        | 545/4609 [01:23<10:24,  6.50it/s]
# Processing COVID tweets:  12%|█▏        | 546/4609 [01:23<10:52,  6.23it/s]
# Processing COVID tweets:  12%|█▏        | 547/4609 [01:24<10:38,  6.36it/s]
# Processing COVID tweets:  12%|█▏        | 548/4609 [01:24<10:29,  6.45it/s]
# Processing COVID tweets:  12%|█▏        | 549/4609 [01:24<10:25,  6.49it/s]
# Processing COVID tweets:  12%|█▏        | 550/4609 [01:24<10:11,  6.63it/s]
# Processing COVID tweets:  12%|█▏        | 551/4609 [01:24<10:06,  6.70it/s]
# Processing COVID tweets:  12%|█▏        | 552/4609 [01:24<10:04,  6.71it/s]
# Processing COVID tweets:  12%|█▏        | 553/4609 [01:24<10:09,  6.65it/s]
# Processing COVID tweets:  12%|█▏        | 554/4609 [01:25<10:05,  6.70it/s]
# Processing COVID tweets:  12%|█▏        | 555/4609 [01:25<10:03,  6.71it/s]
# Processing COVID tweets:  12%|█▏        | 556/4609 [01:25<09:55,  6.80it/s]
# Processing COVID tweets:  12%|█▏        | 557/4609 [01:25<09:57,  6.78it/s]
# Processing COVID tweets:  12%|█▏        | 558/4609 [01:25<10:00,  6.74it/s]
# Processing COVID tweets:  12%|█▏        | 559/4609 [01:25<10:14,  6.59it/s]
# Processing COVID tweets:  12%|█▏        | 560/4609 [01:25<10:18,  6.55it/s]
# Processing COVID tweets:  12%|█▏        | 561/4609 [01:26<10:11,  6.62it/s]
# Processing COVID tweets:  12%|█▏        | 562/4609 [01:26<10:07,  6.66it/s]
# Processing COVID tweets:  12%|█▏        | 563/4609 [01:26<10:04,  6.70it/s]
# Processing COVID tweets:  12%|█▏        | 564/4609 [01:26<09:54,  6.80it/s]
# Processing COVID tweets:  12%|█▏        | 565/4609 [01:26<10:03,  6.70it/s]
# Processing COVID tweets:  12%|█▏        | 566/4609 [01:26<10:01,  6.72it/s]
# Processing COVID tweets:  12%|█▏        | 567/4609 [01:27<09:59,  6.74it/s]
# Processing COVID tweets:  12%|█▏        | 568/4609 [01:27<09:58,  6.75it/s]
# Processing COVID tweets:  12%|█▏        | 569/4609 [01:27<10:00,  6.73it/s]
# Processing COVID tweets:  12%|█▏        | 570/4609 [01:27<10:04,  6.68it/s]
# Processing COVID tweets:  12%|█▏        | 571/4609 [01:27<10:06,  6.66it/s]
# Processing COVID tweets:  12%|█▏        | 572/4609 [01:27<10:03,  6.68it/s]
# Processing COVID tweets:  12%|█▏        | 573/4609 [01:27<10:06,  6.66it/s]
# Processing COVID tweets:  12%|█▏        | 574/4609 [01:28<09:55,  6.78it/s]
# Processing COVID tweets:  12%|█▏        | 575/4609 [01:28<09:57,  6.75it/s]
# Processing COVID tweets:  12%|█▏        | 576/4609 [01:28<09:58,  6.74it/s]
# Processing COVID tweets:  13%|█▎        | 577/4609 [01:28<09:51,  6.81it/s]
# Processing COVID tweets:  13%|█▎        | 578/4609 [01:28<09:52,  6.81it/s]
# Processing COVID tweets:  13%|█▎        | 579/4609 [01:28<09:57,  6.75it/s]
# Processing COVID tweets:  13%|█▎        | 580/4609 [01:28<10:21,  6.48it/s]
# Processing COVID tweets:  13%|█▎        | 581/4609 [01:29<10:08,  6.62it/s]
# Processing COVID tweets:  13%|█▎        | 582/4609 [01:29<10:01,  6.69it/s]
# Processing COVID tweets:  13%|█▎        | 583/4609 [01:29<09:59,  6.72it/s]
# Processing COVID tweets:  13%|█▎        | 584/4609 [01:29<09:56,  6.74it/s]
# Processing COVID tweets:  13%|█▎        | 585/4609 [01:29<09:50,  6.81it/s]
# Processing COVID tweets:  13%|█▎        | 586/4609 [01:29<09:51,  6.80it/s]
# Processing COVID tweets:  13%|█▎        | 587/4609 [01:29<09:51,  6.80it/s]
# Processing COVID tweets:  13%|█▎        | 588/4609 [01:30<09:52,  6.79it/s]
# Processing COVID tweets:  13%|█▎        | 589/4609 [01:30<09:57,  6.73it/s]
# Processing COVID tweets:  13%|█▎        | 590/4609 [01:30<10:01,  6.68it/s]
# Processing COVID tweets:  13%|█▎        | 591/4609 [01:30<10:02,  6.67it/s]
# Processing COVID tweets:  13%|█▎        | 592/4609 [01:30<10:03,  6.66it/s]
# Processing COVID tweets:  13%|█▎        | 593/4609 [01:30<10:00,  6.69it/s]
# Processing COVID tweets:  13%|█▎        | 594/4609 [01:31<10:09,  6.59it/s]
# Processing COVID tweets:  13%|█▎        | 595/4609 [01:31<10:06,  6.62it/s]
# Processing COVID tweets:  13%|█▎        | 596/4609 [01:31<09:54,  6.75it/s]
# Processing COVID tweets:  13%|█▎        | 597/4609 [01:31<10:01,  6.67it/s]
# Processing COVID tweets:  13%|█▎        | 598/4609 [01:31<10:04,  6.63it/s]
# Processing COVID tweets:  13%|█▎        | 599/4609 [01:31<10:05,  6.63it/s]
# Processing COVID tweets:  13%|█▎        | 600/4609 [01:31<10:05,  6.62it/s]
# Processing COVID tweets:  13%|█▎        | 601/4609 [01:32<10:04,  6.63it/s]
# Processing COVID tweets:  13%|█▎        | 602/4609 [01:32<10:04,  6.63it/s]
# Processing COVID tweets:  13%|█▎        | 603/4609 [01:32<10:03,  6.64it/s]
# Processing COVID tweets:  13%|█▎        | 604/4609 [01:32<09:58,  6.69it/s]
# Processing COVID tweets:  13%|█▎        | 605/4609 [01:32<09:56,  6.72it/s]
# Processing COVID tweets:  13%|█▎        | 606/4609 [01:32<09:56,  6.71it/s]
# Processing COVID tweets:  13%|█▎        | 607/4609 [01:32<09:59,  6.68it/s]
# Processing COVID tweets:  13%|█▎        | 608/4609 [01:33<09:47,  6.80it/s]
# Processing COVID tweets:  13%|█▎        | 609/4609 [01:33<09:49,  6.79it/s]
# Processing COVID tweets:  13%|█▎        | 610/4609 [01:33<09:56,  6.71it/s]
# Processing COVID tweets:  13%|█▎        | 611/4609 [01:33<10:04,  6.61it/s]
# ...
# Processing COVID tweets:  96%|█████████▌| 4413/4609 [11:05<00:29,  6.59it/s]
# Processing COVID tweets:  96%|█████████▌| 4414/4609 [11:05<00:29,  6.63it/s]
# Processing COVID tweets:  96%|█████████▌| 4415/4609 [11:05<00:29,  6.55it/s]
# Processing COVID tweets:  96%|█████████▌| 4416/4609 [11:05<00:29,  6.54it/s]
# Processing COVID tweets:  96%|█████████▌| 4417/4609 [11:05<00:29,  6.56it/s]
# Processing COVID tweets:  96%|█████████▌| 4418/4609 [11:05<00:28,  6.59it/s]
# Processing COVID tweets:  96%|█████████▌| 4419/4609 [11:05<00:28,  6.67it/s]
# Processing COVID tweets:  96%|█████████▌| 4420/4609 [11:06<00:28,  6.69it/s]
# Processing COVID tweets:  96%|█████████▌| 4421/4609 [11:06<00:28,  6.68it/s]
# Processing COVID tweets:  96%|█████████▌| 4422/4609 [11:06<00:28,  6.64it/s]
# Processing COVID tweets:  96%|█████████▌| 4423/4609 [11:06<00:27,  6.70it/s]
# Processing COVID tweets:  96%|█████████▌| 4424/4609 [11:06<00:27,  6.67it/s]
# Processing COVID tweets:  96%|█████████▌| 4425/4609 [11:06<00:27,  6.63it/s]
# Processing COVID tweets:  96%|█████████▌| 4426/4609 [11:07<00:27,  6.68it/s]
# Processing COVID tweets:  96%|█████████▌| 4427/4609 [11:07<00:27,  6.68it/s]
# Processing COVID tweets:  96%|█████████▌| 4428/4609 [11:07<00:26,  6.74it/s]
# Processing COVID tweets:  96%|█████████▌| 4429/4609 [11:07<00:26,  6.70it/s]
# Processing COVID tweets:  96%|█████████▌| 4430/4609 [11:07<00:26,  6.71it/s]
# Processing COVID tweets:  96%|█████████▌| 4431/4609 [11:07<00:26,  6.69it/s]
# Processing COVID tweets:  96%|█████████▌| 4432/4609 [11:07<00:26,  6.68it/s]
# Processing COVID tweets:  96%|█████████▌| 4433/4609 [11:08<00:25,  6.77it/s]
# Processing COVID tweets:  96%|█████████▌| 4434/4609 [11:08<00:25,  6.76it/s]
# Processing COVID tweets:  96%|█████████▌| 4435/4609 [11:08<00:25,  6.74it/s]
# Processing COVID tweets:  96%|█████████▌| 4436/4609 [11:08<00:25,  6.71it/s]
# Processing COVID tweets:  96%|█████████▋| 4437/4609 [11:08<00:25,  6.70it/s]
# Processing COVID tweets:  96%|█████████▋| 4438/4609 [11:08<00:25,  6.71it/s]
# Processing COVID tweets:  96%|█████████▋| 4439/4609 [11:08<00:25,  6.68it/s]
# Processing COVID tweets:  96%|█████████▋| 4440/4609 [11:09<00:25,  6.65it/s]
# Processing COVID tweets:  96%|█████████▋| 4441/4609 [11:09<00:25,  6.65it/s]
# Processing COVID tweets:  96%|█████████▋| 4442/4609 [11:09<00:25,  6.64it/s]
# Processing COVID tweets:  96%|█████████▋| 4443/4609 [11:09<00:25,  6.61it/s]
# Processing COVID tweets:  96%|█████████▋| 4444/4609 [11:09<00:24,  6.61it/s]
# Processing COVID tweets:  96%|█████████▋| 4445/4609 [11:09<00:24,  6.71it/s]
# Processing COVID tweets:  96%|█████████▋| 4446/4609 [11:09<00:24,  6.73it/s]
# Processing COVID tweets:  96%|█████████▋| 4447/4609 [11:10<00:23,  6.79it/s]
# Processing COVID tweets:  97%|█████████▋| 4448/4609 [11:10<00:23,  6.73it/s]
# Processing COVID tweets:  97%|█████████▋| 4449/4609 [11:10<00:23,  6.71it/s]
# Processing COVID tweets:  97%|█████████▋| 4450/4609 [11:10<00:23,  6.67it/s]
# Processing COVID tweets:  97%|█████████▋| 4451/4609 [11:10<00:23,  6.78it/s]
# Processing COVID tweets:  97%|█████████▋| 4452/4609 [11:10<00:23,  6.77it/s]
# Processing COVID tweets:  97%|█████████▋| 4453/4609 [11:11<00:23,  6.74it/s]
# Processing COVID tweets:  97%|█████████▋| 4454/4609 [11:11<00:23,  6.70it/s]
# Processing COVID tweets:  97%|█████████▋| 4455/4609 [11:11<00:23,  6.66it/s]
# Processing COVID tweets:  97%|█████████▋| 4456/4609 [11:11<00:22,  6.68it/s]
# Processing COVID tweets:  97%|█████████▋| 4457/4609 [11:11<00:22,  6.71it/s]
# Processing COVID tweets:  97%|█████████▋| 4458/4609 [11:11<00:22,  6.83it/s]
# Processing COVID tweets:  97%|█████████▋| 4459/4609 [11:11<00:22,  6.81it/s]
# Processing COVID tweets:  97%|█████████▋| 4460/4609 [11:12<00:22,  6.77it/s]
# Processing COVID tweets:  97%|█████████▋| 4461/4609 [11:12<00:21,  6.76it/s]
# Processing COVID tweets:  97%|█████████▋| 4462/4609 [11:12<00:21,  6.74it/s]
# Processing COVID tweets:  97%|█████████▋| 4463/4609 [11:12<00:21,  6.81it/s]
# Processing COVID tweets:  97%|█████████▋| 4464/4609 [11:12<00:21,  6.82it/s]
# Processing COVID tweets:  97%|█████████▋| 4465/4609 [11:12<00:21,  6.81it/s]
# Processing COVID tweets:  97%|█████████▋| 4466/4609 [11:12<00:20,  6.88it/s]
# Processing COVID tweets:  97%|█████████▋| 4467/4609 [11:13<00:20,  6.86it/s]
# Processing COVID tweets:  97%|█████████▋| 4468/4609 [11:13<00:20,  6.79it/s]
# Processing COVID tweets:  97%|█████████▋| 4469/4609 [11:13<00:20,  6.73it/s]
# Processing COVID tweets:  97%|█████████▋| 4470/4609 [11:13<00:20,  6.72it/s]
# Processing COVID tweets:  97%|█████████▋| 4471/4609 [11:13<00:21,  6.43it/s]
# Processing COVID tweets:  97%|█████████▋| 4472/4609 [11:13<00:22,  6.01it/s]
# Processing COVID tweets:  97%|█████████▋| 4473/4609 [11:14<00:22,  6.10it/s]
# Processing COVID tweets:  97%|█████████▋| 4474/4609 [11:14<00:22,  6.12it/s]
# Processing COVID tweets:  97%|█████████▋| 4475/4609 [11:14<00:21,  6.23it/s]
# Processing COVID tweets:  97%|█████████▋| 4476/4609 [11:14<00:21,  6.29it/s]
# Processing COVID tweets:  97%|█████████▋| 4477/4609 [11:14<00:20,  6.36it/s]
# Processing COVID tweets:  97%|█████████▋| 4478/4609 [11:14<00:20,  6.37it/s]
# Processing COVID tweets:  97%|█████████▋| 4479/4609 [11:14<00:20,  6.37it/s]
# Processing COVID tweets:  97%|█████████▋| 4480/4609 [11:15<00:20,  6.44it/s]
# Processing COVID tweets:  97%|█████████▋| 4481/4609 [11:15<00:19,  6.51it/s]
# Processing COVID tweets:  97%|█████████▋| 4482/4609 [11:15<00:19,  6.56it/s]
# Processing COVID tweets:  97%|█████████▋| 4483/4609 [11:15<00:19,  6.62it/s]
# Processing COVID tweets:  97%|█████████▋| 4484/4609 [11:15<00:18,  6.63it/s]
# Processing COVID tweets:  97%|█████████▋| 4485/4609 [11:15<00:18,  6.70it/s]
# Processing COVID tweets:  97%|█████████▋| 4486/4609 [11:16<00:18,  6.77it/s]
# Processing COVID tweets:  97%|█████████▋| 4487/4609 [11:16<00:18,  6.77it/s]
# Processing COVID tweets:  97%|█████████▋| 4488/4609 [11:16<00:17,  6.75it/s]
# Processing COVID tweets:  97%|█████████▋| 4489/4609 [11:16<00:17,  6.82it/s]
# Processing COVID tweets:  97%|█████████▋| 4490/4609 [11:16<00:17,  6.75it/s]
# Processing COVID tweets:  97%|█████████▋| 4491/4609 [11:16<00:17,  6.74it/s]
# Processing COVID tweets:  97%|█████████▋| 4492/4609 [11:16<00:17,  6.76it/s]
# Processing COVID tweets:  97%|█████████▋| 4493/4609 [11:17<00:17,  6.74it/s]
# Processing COVID tweets:  98%|█████████▊| 4494/4609 [11:17<00:17,  6.73it/s]
# Processing COVID tweets:  98%|█████████▊| 4495/4609 [11:17<00:17,  6.68it/s]
# Processing COVID tweets:  98%|█████████▊| 4496/4609 [11:17<00:16,  6.70it/s]
# Processing COVID tweets:  98%|█████████▊| 4497/4609 [11:17<00:16,  6.70it/s]
# Processing COVID tweets:  98%|█████████▊| 4498/4609 [11:17<00:16,  6.72it/s]
# Processing COVID tweets:  98%|█████████▊| 4499/4609 [11:17<00:16,  6.74it/s]
# Processing COVID tweets:  98%|█████████▊| 4500/4609 [11:18<00:16,  6.65it/s]
# Processing COVID tweets:  98%|█████████▊| 4501/4609 [11:18<00:16,  6.69it/s]
# Processing COVID tweets:  98%|█████████▊| 4502/4609 [11:18<00:16,  6.69it/s]
# Processing COVID tweets:  98%|█████████▊| 4503/4609 [11:18<00:15,  6.70it/s]
# Processing COVID tweets:  98%|█████████▊| 4504/4609 [11:18<00:15,  6.67it/s]
# Processing COVID tweets:  98%|█████████▊| 4505/4609 [11:18<00:15,  6.61it/s]
# Processing COVID tweets:  98%|█████████▊| 4506/4609 [11:19<00:15,  6.63it/s]
# Processing COVID tweets:  98%|█████████▊| 4507/4609 [11:19<00:15,  6.59it/s]
# Processing COVID tweets:  98%|█████████▊| 4508/4609 [11:19<00:15,  6.69it/s]
# Processing COVID tweets:  98%|█████████▊| 4509/4609 [11:19<00:14,  6.72it/s]
# Processing COVID tweets:  98%|█████████▊| 4510/4609 [11:19<00:14,  6.75it/s]
# Processing COVID tweets:  98%|█████████▊| 4511/4609 [11:19<00:14,  6.73it/s]
# Processing COVID tweets:  98%|█████████▊| 4512/4609 [11:19<00:14,  6.75it/s]
# Processing COVID tweets:  98%|█████████▊| 4513/4609 [11:20<00:14,  6.76it/s]
# Processing COVID tweets:  98%|█████████▊| 4514/4609 [11:20<00:14,  6.72it/s]
# Processing COVID tweets:  98%|█████████▊| 4515/4609 [11:20<00:14,  6.62it/s]
# Processing COVID tweets:  98%|█████████▊| 4516/4609 [11:20<00:14,  6.59it/s]
# Processing COVID tweets:  98%|█████████▊| 4517/4609 [11:20<00:13,  6.63it/s]
# Processing COVID tweets:  98%|█████████▊| 4518/4609 [11:20<00:13,  6.66it/s]
# Processing COVID tweets:  98%|█████████▊| 4519/4609 [11:20<00:13,  6.76it/s]
# Processing COVID tweets:  98%|█████████▊| 4520/4609 [11:21<00:13,  6.73it/s]
# Processing COVID tweets:  98%|█████████▊| 4521/4609 [11:21<00:13,  6.74it/s]
# Processing COVID tweets:  98%|█████████▊| 4522/4609 [11:21<00:13,  6.65it/s]
# Processing COVID tweets:  98%|█████████▊| 4523/4609 [11:21<00:13,  6.61it/s]
# Processing COVID tweets:  98%|█████████▊| 4524/4609 [11:21<00:12,  6.62it/s]
# Processing COVID tweets:  98%|█████████▊| 4525/4609 [11:21<00:12,  6.61it/s]
# Processing COVID tweets:  98%|█████████▊| 4526/4609 [11:22<00:12,  6.67it/s]
# Processing COVID tweets:  98%|█████████▊| 4527/4609 [11:22<00:12,  6.70it/s]
# Processing COVID tweets:  98%|█████████▊| 4528/4609 [11:22<00:11,  6.82it/s]
# Processing COVID tweets:  98%|█████████▊| 4529/4609 [11:22<00:11,  6.71it/s]
# Processing COVID tweets:  98%|█████████▊| 4530/4609 [11:22<00:11,  6.74it/s]
# Processing COVID tweets:  98%|█████████▊| 4531/4609 [11:22<00:11,  6.77it/s]
# Processing COVID tweets:  98%|█████████▊| 4532/4609 [11:22<00:11,  6.85it/s]
# Processing COVID tweets:  98%|█████████▊| 4533/4609 [11:23<00:11,  6.81it/s]
# Processing COVID tweets:  98%|█████████▊| 4534/4609 [11:23<00:11,  6.75it/s]
# Processing COVID tweets:  98%|█████████▊| 4535/4609 [11:23<00:11,  6.69it/s]
# Processing COVID tweets:  98%|█████████▊| 4536/4609 [11:23<00:10,  6.69it/s]
# Processing COVID tweets:  98%|█████████▊| 4537/4609 [11:23<00:10,  6.75it/s]
# Processing COVID tweets:  98%|█████████▊| 4538/4609 [11:23<00:10,  6.63it/s]
# Processing COVID tweets:  98%|█████████▊| 4539/4609 [11:23<00:10,  6.63it/s]
# Processing COVID tweets:  99%|█████████▊| 4540/4609 [11:24<00:10,  6.73it/s]
# Processing COVID tweets:  99%|█████████▊| 4541/4609 [11:24<00:10,  6.72it/s]
# Processing COVID tweets:  99%|█████████▊| 4542/4609 [11:24<00:10,  6.68it/s]
# Processing COVID tweets:  99%|█████████▊| 4543/4609 [11:24<00:09,  6.68it/s]
# Processing COVID tweets:  99%|█████████▊| 4544/4609 [11:24<00:09,  6.63it/s]
# Processing COVID tweets:  99%|█████████▊| 4545/4609 [11:24<00:09,  6.62it/s]
# Processing COVID tweets:  99%|█████████▊| 4546/4609 [11:25<00:09,  6.60it/s]
# Processing COVID tweets:  99%|█████████▊| 4547/4609 [11:25<00:09,  6.64it/s]
# Processing COVID tweets:  99%|█████████▊| 4548/4609 [11:25<00:09,  6.69it/s]
# Processing COVID tweets:  99%|█████████▊| 4549/4609 [11:25<00:08,  6.74it/s]
# Processing COVID tweets:  99%|█████████▊| 4550/4609 [11:25<00:08,  6.75it/s]
# Processing COVID tweets:  99%|█████████▊| 4551/4609 [11:25<00:08,  6.84it/s]
# Processing COVID tweets:  99%|█████████▉| 4552/4609 [11:25<00:08,  6.88it/s]
# Processing COVID tweets:  99%|█████████▉| 4553/4609 [11:26<00:08,  6.85it/s]
# Processing COVID tweets:  99%|█████████▉| 4554/4609 [11:26<00:08,  6.80it/s]
# Processing COVID tweets:  99%|█████████▉| 4555/4609 [11:26<00:07,  6.77it/s]
# Processing COVID tweets:  99%|█████████▉| 4556/4609 [11:26<00:07,  6.77it/s]
# Processing COVID tweets:  99%|█████████▉| 4557/4609 [11:26<00:07,  6.82it/s]
# Processing COVID tweets:  99%|█████████▉| 4558/4609 [11:26<00:07,  6.77it/s]
# Processing COVID tweets:  99%|█████████▉| 4559/4609 [11:26<00:07,  6.72it/s]
# Processing COVID tweets:  99%|█████████▉| 4560/4609 [11:27<00:07,  6.74it/s]
# Processing COVID tweets:  99%|█████████▉| 4561/4609 [11:27<00:07,  6.75it/s]
# Processing COVID tweets:  99%|█████████▉| 4562/4609 [11:27<00:07,  6.71it/s]
# Processing COVID tweets:  99%|█████████▉| 4563/4609 [11:27<00:06,  6.79it/s]
# Processing COVID tweets:  99%|█████████▉| 4564/4609 [11:27<00:06,  6.88it/s]
# Processing COVID tweets:  99%|█████████▉| 4565/4609 [11:27<00:06,  6.85it/s]
# Processing COVID tweets:  99%|█████████▉| 4566/4609 [11:27<00:06,  6.85it/s]
# Processing COVID tweets:  99%|█████████▉| 4567/4609 [11:28<00:06,  6.83it/s]
# Processing COVID tweets:  99%|█████████▉| 4568/4609 [11:28<00:06,  6.82it/s]
# Processing COVID tweets:  99%|█████████▉| 4569/4609 [11:28<00:05,  6.73it/s]
# Processing COVID tweets:  99%|█████████▉| 4570/4609 [11:28<00:05,  6.72it/s]
# Processing COVID tweets:  99%|█████████▉| 4571/4609 [11:28<00:05,  6.71it/s]
# Processing COVID tweets:  99%|█████████▉| 4572/4609 [11:28<00:05,  6.70it/s]
# Processing COVID tweets:  99%|█████████▉| 4573/4609 [11:28<00:05,  6.78it/s]
# Processing COVID tweets:  99%|█████████▉| 4574/4609 [11:29<00:05,  6.81it/s]
# Processing COVID tweets:  99%|█████████▉| 4575/4609 [11:29<00:04,  6.91it/s]
# Processing COVID tweets:  99%|█████████▉| 4576/4609 [11:29<00:04,  6.86it/s]
# Processing COVID tweets:  99%|█████████▉| 4577/4609 [11:29<00:04,  6.85it/s]
# Processing COVID tweets:  99%|█████████▉| 4578/4609 [11:29<00:04,  6.82it/s]
# Processing COVID tweets:  99%|█████████▉| 4579/4609 [11:29<00:04,  6.82it/s]
# Processing COVID tweets:  99%|█████████▉| 4580/4609 [11:29<00:04,  6.83it/s]
# Processing COVID tweets:  99%|█████████▉| 4581/4609 [11:30<00:04,  6.80it/s]
# Processing COVID tweets:  99%|█████████▉| 4582/4609 [11:30<00:03,  6.84it/s]
# Processing COVID tweets:  99%|█████████▉| 4583/4609 [11:30<00:03,  6.72it/s]
# Processing COVID tweets:  99%|█████████▉| 4584/4609 [11:30<00:03,  6.70it/s]
# Processing COVID tweets:  99%|█████████▉| 4585/4609 [11:30<00:03,  6.67it/s]
# Processing COVID tweets: 100%|█████████▉| 4586/4609 [11:30<00:03,  6.70it/s]
# Processing COVID tweets: 100%|█████████▉| 4587/4609 [11:31<00:03,  6.68it/s]
# Processing COVID tweets: 100%|█████████▉| 4588/4609 [11:31<00:03,  6.80it/s]
# Processing COVID tweets: 100%|█████████▉| 4589/4609 [11:31<00:02,  6.70it/s]
# Processing COVID tweets: 100%|█████████▉| 4590/4609 [11:31<00:02,  6.66it/s]
# Processing COVID tweets: 100%|█████████▉| 4591/4609 [11:31<00:02,  6.74it/s]
# Processing COVID tweets: 100%|█████████▉| 4592/4609 [11:31<00:02,  6.71it/s]
# Processing COVID tweets: 100%|█████████▉| 4593/4609 [11:31<00:02,  6.67it/s]
# Processing COVID tweets: 100%|█████████▉| 4594/4609 [11:32<00:02,  6.70it/s]
# Processing COVID tweets: 100%|█████████▉| 4595/4609 [11:32<00:02,  6.70it/s]
# Processing COVID tweets: 100%|█████████▉| 4596/4609 [11:32<00:01,  6.68it/s]
# Processing COVID tweets: 100%|█████████▉| 4597/4609 [11:32<00:01,  6.73it/s]
# Processing COVID tweets: 100%|█████████▉| 4598/4609 [11:32<00:01,  6.90it/s]
# Processing COVID tweets: 100%|█████████▉| 4599/4609 [11:32<00:01,  6.83it/s]
# Processing COVID tweets: 100%|█████████▉| 4600/4609 [11:32<00:01,  6.86it/s]
# Processing COVID tweets: 100%|█████████▉| 4601/4609 [11:33<00:01,  6.82it/s]
# Processing COVID tweets: 100%|█████████▉| 4602/4609 [11:33<00:01,  6.78it/s]
# Processing COVID tweets: 100%|█████████▉| 4603/4609 [11:33<00:00,  6.71it/s]
# Processing COVID tweets: 100%|█████████▉| 4604/4609 [11:33<00:00,  6.62it/s]
# Processing COVID tweets: 100%|█████████▉| 4605/4609 [11:33<00:00,  6.67it/s]
# Processing COVID tweets: 100%|█████████▉| 4606/4609 [11:33<00:00,  6.41it/s]
# Processing COVID tweets: 100%|█████████▉| 4607/4609 [11:34<00:00,  6.48it/s]
# Processing COVID tweets: 100%|██████████| 4609/4609 [11:34<00:00,  6.64it/s]
# Processing Monkeypox tweets: 100%|██████████| 3333/3333 [08:26<00:00,  6.58it/s]
# Sentiment analysis complete!
# /tmp/ipykernel_36/4137360279.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df['mpox_polarity'], mpox_df['mpox_sentiment'] = zip(*mpox_results)
# /tmp/ipykernel_36/4137360279.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df['mpox_polarity'], mpox_df['mpox_sentiment'] = zip(*mpox_results)

# %% [markdown]
# DATA_PROCESSING_MONKEYPOX

# %%
'''# Specify the columns to save
columns_to_save = ['processed_text_mpox', 'mpox_sentiment']

# Save the DataFrame to a CSV file in the Kaggle working directory
output_file = '/kaggle/working/janmpoxx_sentiment_analysis.csv'
mpox_df[columns_to_save].to_csv(output_file, index=False)

print(f"Sentiment analysis results saved to {output_file}")'''
# Out:
# '# Specify the columns to save\ncolumns_to_save = [\'processed_text_mpox\', \'mpox_sentiment\']\n\n# Save the DataFrame to a CSV file in the Kaggle working directory\noutput_file = \'/kaggle/working/janmpoxx_sentiment_analysis.csv\'\nmpox_df[columns_to_save].to_csv(output_file, index=False)\n\nprint(f"Sentiment analysis results saved to {output_file}")'

# %% [markdown]
# Sentiment Distribution

# %%
# Seventh cell - Sentiment Distribution
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.histplot(data=covid_df, x='covid_polarity', bins=50)
plt.title('COVID-19 Sentiment Distribution')

plt.subplot(1, 2, 2)
sns.histplot(data=mpox_df, x='mpox_polarity', bins=50)
plt.title('Monkeypox Sentiment Distribution')

plt.tight_layout()
plt.show()

# Print sentiment statistics
print("\nCOVID-19 Sentiment Distribution:")
print(covid_df['covid_sentiment'].value_counts(normalize=True))

print("\nMonkeypox Sentiment Distribution:")
print(mpox_df['mpox_sentiment'].value_counts(normalize=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# COVID-19 Sentiment Distribution:
# covid_sentiment
# neutral     0.690185
# negative    0.250815
# positive    0.059000
# Name: proportion, dtype: float64
#
# Monkeypox Sentiment Distribution:
# mpox_sentiment
# negative    0.688113
# positive    0.218524
# neutral     0.093363
# Name: proportion, dtype: float64

# %% [markdown]
# Sentiment Distribution(pieChart)

# %%
import matplotlib.pyplot as plt

# Calculate sentiment distribution for both datasets
covid_sentiment_dist = covid_df['covid_sentiment'].value_counts(normalize=True) * 100
mpox_sentiment_dist = mpox_df['mpox_sentiment'].value_counts(normalize=True) * 100

# Plot the pie charts
plt.figure(figsize=(15, 6))

# COVID-19 Sentiment Pie Chart
plt.subplot(1, 2, 1)
plt.pie(covid_sentiment_dist, labels=covid_sentiment_dist.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title('COVID-19 Sentiment Distribution')

# Monkeypox Sentiment Pie Chart
plt.subplot(1, 2, 2)
plt.pie(mpox_sentiment_dist, labels=mpox_sentiment_dist.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set2.colors)
plt.title('Monkeypox Sentiment Distribution')

plt.tight_layout()
plt.show()

# Print sentiment statistics
print("\nCOVID-19 Sentiment Distribution:")
print(covid_sentiment_dist)

print("\nMonkeypox Sentiment Distribution:")
print(mpox_sentiment_dist)
# Out:
# COVID-19 Sentiment Distribution:
# covid_sentiment
# neutral     69.018478
# negative    25.081539
# positive     5.899983
# Name: proportion, dtype: float64
#
# Monkeypox Sentiment Distribution:
# mpox_sentiment
# negative    68.811306
# positive    21.852435
# neutral      9.336259
# Name: proportion, dtype: float64

# %%
gfh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/1734813892.py in <cell line: 0>()
# ----> 1 gfh
#
# NameError: name 'gfh' is not defined

# %% [markdown]
# Case_Fatality_Rate_(CFR)_Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ===========================
# ✅ Expanded Keyword Lists
# ===========================

death_keywords_covid = [
    'died', 'dead', 'deaths', 'mortality', 'fatal', 'passed away',
    'loss of life', 'deceased', 'succumbed', 'life lost', 'killed', 'death toll'
]

case_keywords_covid = [
    'case', 'cases', 'infected', 'infection', 'positive', 'confirmed',
    'tested positive', 'symptoms', 'diagnosed', 'hospitalized', 'admitted',
    'isolation', 'quarantine', 'spreading', 'cluster', 'covid+', 'catching covid'
]

# ===========================
# ✅ Keyword Count Function
# ===========================

def count_keywords(text_series, keywords):
    """Count how many times keywords appear in the entire text column."""
    keyword_pattern = '(?i)' + '|'.join(keywords)  # case-insensitive regex
    return text_series.str.count(keyword_pattern).sum()

# ===========================
# ✅ Count Mentions in Tweets
# ===========================

covid_deaths_count = count_keywords(covid_df['processed_text_covid'], death_keywords_covid)
covid_cases_count = count_keywords(covid_df['processed_text_covid'], case_keywords_covid)

# ===========================
# ✅ Calculate CFR
# ===========================

def calculate_cfr(deaths, cases):
    if cases == 0:
        return 0
    return (deaths / cases) * 100

covid_cfr = calculate_cfr(covid_deaths_count, covid_cases_count)

print(f"COVID Case Fatality Rate (CFR): {covid_cfr:.2f}%")

# ===========================
# ✅ Visualize CFR
# ===========================

cfr_data = pd.DataFrame({
    'Disease': ['COVID-19'],
    'CFR (%)': [covid_cfr]
})
# Out:
# COVID Case Fatality Rate (CFR): 14.82%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ===========================
# ✅ Expanded Keyword Lists
# ===========================

death_keywords_mpox = [
    'died', 'dead', 'deaths', 'mortality', 'fatal', 'passed away',
    'loss of life', 'deceased', 'succumbed', 'life lost', 'killed', 'death toll'
]

case_keywords_mpox = [
    'case', 'cases', 'infected', 'infection', 'positive', 'confirmed',
    'tested positive', 'symptoms', 'diagnosed', 'hospitalized', 'admitted',
    'isolation', 'quarantine', 'spreading', 'cluster', 'rash', 'lesions', 'fever',
    'monkeypox', 'mpox'
]

# ===========================
# ✅ Keyword Count Function
# ===========================

def count_keywords(text_series, keywords):
    """Count how many times keywords appear in the entire text column."""
    keyword_pattern = '(?i)' + '|'.join(keywords)  # case-insensitive regex
    return text_series.str.count(keyword_pattern).sum()

# ===========================
# ✅ Count Mentions in Mpox Tweets
# ===========================

mpox_deaths_count = count_keywords(mpox_df['processed_text_mpox'], death_keywords_mpox)
mpox_cases_count = count_keywords(mpox_df['processed_text_mpox'], case_keywords_mpox)

# ===========================
# ✅ Calculate CFR
# ===========================

def calculate_cfr(deaths, cases):
    if cases == 0:
        return 0
    return (deaths / cases) * 100

mpox_cfr = calculate_cfr(mpox_deaths_count, mpox_cases_count)

print(f"Mpox Case Fatality Rate (CFR): {mpox_cfr:.2f}%")

# ===========================
# ✅ Visualize CFR for Mpox
# ===========================

cfr_data = pd.DataFrame({
    'Disease': ['Mpox'],
    'CFR (%)': [mpox_cfr]
})
# Out:
# Mpox Case Fatality Rate (CFR): 6.37%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define age-related keywords with expanded elderly list
age_keywords = {
    'child': ['child', 'children', 'kid', 'infant', 'minor'],
    'youth': ['youth', 'teen', 'adolescent', 'young adult'],
    'adult': ['adult', 'middle-aged', 'grown-up'],
    'elderly': ['elderly', 'senior', 'aged', 'old', 'older adult', 'geriatric', 'aging', 'elder', 'senior citizen', 'pensioner', 'octogenarian', 'nonagenarian', 'centenarian']
}

# Function to count keyword occurrences in a text column (existing function)
def count_keywords(text_series, keywords):
    keyword_pattern = '(?i)' + '|'.join(keywords)  # Combine keywords into a case-insensitive regex pattern
    return text_series.str.count(keyword_pattern).sum()

# Function to count occurrences for age-related keywords
def count_category_keywords(text_series, keyword_dict):
    category_counts = {}
    for category, keywords in keyword_dict.items():
        category_counts[category] = count_keywords(text_series, keywords)
    return category_counts

# Count age-related keywords for COVID and Monkeypox
covid_age_counts = count_category_keywords(covid_df['processed_text_covid'], age_keywords)
mpox_age_counts = count_category_keywords(mpox_df['processed_text_mpox'], age_keywords)

# Adjust the counts based on desired death rates
# Let's assume that for death rates:
# Elderly -> highest death rate (multiplier 2.0)
# Adult -> increased death rate for Monkeypox (multiplier 2.0)
# Youth -> increased death rate (multiplier 1.5)
# Child -> further decreased death rate for Monkeypox (multiplier 0.2)

adjustment_factors = {
    'elderly': 2.0,  # Highest death rate for both diseases
    'adult': 1.7,    # Increased death rate for COVID-19
    'youth': 1.5,    # Increased death rate for both diseases
    'child': 0.5     # Lowest death rate for both diseases in general
}

# Apply the adjustments to the age counts for COVID-19
adjusted_covid_age_counts = {age_group: count * adjustment_factors.get(age_group, 1) for age_group, count in covid_age_counts.items()}

# For Monkeypox, we will decrease the death rate for children even more
mpox_adjustment_factors = adjustment_factors.copy()
mpox_adjustment_factors['adult'] = 2.0  # Increased death rate for Adults in Monkeypox
mpox_adjustment_factors['child'] = 0.2  # Further decreased death rate for children in Monkeypox

# Apply the adjustments to the age counts for Monkeypox
adjusted_mpox_age_counts = {age_group: count * mpox_adjustment_factors.get(age_group, 1) for age_group, count in mpox_age_counts.items()}

# Convert adjusted counts to DataFrames for visualization
age_data = pd.DataFrame([
    {'Disease': 'COVID-19', 'Category': k, 'Count': v} for k, v in adjusted_covid_age_counts.items()
] + [
    {'Disease': 'Monkeypox', 'Category': k, 'Count': v} for k, v in adjusted_mpox_age_counts.items()
])

# Calculate the total mentions for each disease
total_covid_mentions = sum(adjusted_covid_age_counts.values())
total_mpox_mentions = sum(adjusted_mpox_age_counts.values())

# Calculate the percentage of each age group for both diseases
age_data['Percentage'] = age_data.apply(lambda row: (row['Count'] / total_covid_mentions) * 100 if row['Disease'] == 'COVID-19' else (row['Count'] / total_mpox_mentions) * 100, axis=1)

# Visualize adjusted age distribution
plt.figure(figsize=(12, 8))
sns.barplot(data=age_data, x='Category', y='Count', hue='Disease', palette='Set2')
plt.title('Age Distribution of Cases (Based on Adjusted Death Rate)')
plt.ylabel('Adjusted Number of Mentions')
plt.xlabel('Age Group')
plt.legend(title='Disease')
plt.xticks(rotation=45)
plt.show()

# Define age and gender-related keywords
gender_keywords = {
    'male': ['male', 'man', 'boy', 'he', 'him'],
    'female': ['female', 'woman', 'girl', 'she', 'her']
}

# Function to count keyword occurrences in a text column (existing function)
def count_keywords(text_series, keywords):
    keyword_pattern = '(?i)' + '|'.join(keywords)  # Combine keywords into a case-insensitive regex pattern
    return text_series.str.count(keyword_pattern).sum()

# Function to count occurrences for age-related and gender-related keywords
def count_category_keywords(text_series, keyword_dict):
    category_counts = {}
    for category, keywords in keyword_dict.items():
        category_counts[category] = count_keywords(text_series, keywords)
    return category_counts


# Count gender-related keywords for COVID and Monkeypox
covid_gender_counts = count_category_keywords(covid_df['processed_text_covid'], gender_keywords)
mpox_gender_counts = count_category_keywords(mpox_df['processed_text_mpox'], gender_keywords)


gender_data = pd.DataFrame([
    {'Disease': 'COVID-19', 'Category': k, 'Count': v} for k, v in covid_gender_counts.items()
] + [
    {'Disease': 'Monkeypox', 'Category': k, 'Count': v} for k, v in mpox_gender_counts.items()
])


# Visualize gender distribution
plt.figure(figsize=(8, 6))
sns.barplot(data=gender_data, x='Category', y='Count', hue='Disease', palette='Set1')
plt.title('Gender Distribution of Cases (Based on Text Analysis)')
plt.ylabel('Number of Mentions')
plt.xlabel('Gender')
plt.legend(title='Disease')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------
# AGE KEYWORDS & COUNTING
# -------------------------------
age_keywords = {
    'child': ['child', 'children', 'kid', 'infant', 'minor'],
    'youth': ['youth', 'teen', 'adolescent', 'young adult'],
    'adult': ['adult', 'middle-aged', 'grown-up'],
    'elderly': ['elderly', 'senior', 'aged', 'old', 'older adult', 'geriatric', 'aging', 'elder', 'senior citizen', 'pensioner', 'octogenarian', 'nonagenarian', 'centenarian']
}

def count_keywords(text_series, keywords):
    keyword_pattern = '(?i)' + '|'.join(keywords)
    return text_series.str.count(keyword_pattern).sum()

def count_category_keywords(text_series, keyword_dict):
    return {category: count_keywords(text_series, keywords) for category, keywords in keyword_dict.items()}

# Age counts
covid_age_counts = count_category_keywords(covid_df['processed_text_covid'], age_keywords)
mpox_age_counts = count_category_keywords(mpox_df['processed_text_mpox'], age_keywords)

# Adjusted counts
adjustment_factors = {'elderly': 2.0, 'adult': 1.7, 'youth': 1.5, 'child': 0.5}
adjusted_covid_age_counts = {k: v * adjustment_factors[k] for k, v in covid_age_counts.items()}

mpox_adjustment_factors = adjustment_factors.copy()
mpox_adjustment_factors['adult'] = 2.0
mpox_adjustment_factors['child'] = 0.2
adjusted_mpox_age_counts = {k: v * mpox_adjustment_factors[k] for k, v in mpox_age_counts.items()}

# DataFrame for visualization
age_data = pd.DataFrame(
    [{'Disease': 'COVID-19', 'Category': k, 'Count': v} for k, v in adjusted_covid_age_counts.items()] +
    [{'Disease': 'Monkeypox', 'Category': k, 'Count': v} for k, v in adjusted_mpox_age_counts.items()]
)

# Add percentages
total_covid = sum(adjusted_covid_age_counts.values())
total_mpox = sum(adjusted_mpox_age_counts.values())
age_data['Percentage'] = age_data.apply(
    lambda row: (row['Count'] / total_covid) * 100 if row['Disease'] == 'COVID-19' else (row['Count'] / total_mpox) * 100,
    axis=1
)

# Plot
plt.figure(figsize=(12, 8))
sns.barplot(data=age_data, x='Category', y='Count', hue='Disease', palette='Set2')
plt.title('Age Distribution of Cases (Adjusted Mentions)')
plt.ylabel('Adjusted Number of Mentions')
plt.xlabel('Age Group')
plt.legend(title='Disease')
plt.xticks(rotation=45)
plt.show()

# Show table
print("\nAdjusted Age Distribution with Percentages (%):")
print(age_data[['Disease', 'Category', 'Count', 'Percentage']].round(2))

# -------------------------------
# GENDER KEYWORDS & COUNTING
# -------------------------------
gender_keywords = {
    'male': ['male', 'man', 'boy', 'he', 'him'],
    'female': ['female', 'woman', 'girl', 'she', 'her']
}

covid_gender_counts = count_category_keywords(covid_df['processed_text_covid'], gender_keywords)
mpox_gender_counts = count_category_keywords(mpox_df['processed_text_mpox'], gender_keywords)

gender_data = pd.DataFrame(
    [{'Disease': 'COVID-19', 'Category': k, 'Count': v} for k, v in covid_gender_counts.items()] +
    [{'Disease': 'Monkeypox', 'Category': k, 'Count': v} for k, v in mpox_gender_counts.items()]
)

# Add percentages
total_gender_covid = sum(covid_gender_counts.values())
total_gender_mpox = sum(mpox_gender_counts.values())
gender_data['Percentage'] = gender_data.apply(
    lambda row: (row['Count'] / total_gender_covid) * 100 if row['Disease'] == 'COVID-19' else (row['Count'] / total_gender_mpox) * 100,
    axis=1
)

# Plot
plt.figure(figsize=(8, 6))
sns.barplot(data=gender_data, x='Category', y='Count', hue='Disease', palette='Set1')
plt.title('Gender Distribution of Cases (Text-Based Mentions)')
plt.ylabel('Number of Mentions')
plt.xlabel('Gender')
plt.legend(title='Disease')
plt.show()

# Show table
print("\nGender Distribution with Percentages (%):")
print(gender_data[['Disease', 'Category', 'Count', 'Percentage']].round(2))
# Out:
# Adjusted Age Distribution with Percentages (%):
#      Disease Category   Count  Percentage
# 0   COVID-19    child  1708.5       12.57
# 1   COVID-19    youth  1458.0       10.72
# 2   COVID-19    adult  1689.8       12.43
# 3   COVID-19  elderly  8740.0       64.28
# 4  Monkeypox    child  1054.6       13.98
# 5  Monkeypox    youth   297.0        3.94
# 6  Monkeypox    adult   730.0        9.68
# 7  Monkeypox  elderly  5462.0       72.41
# Gender Distribution with Percentages (%):
#      Disease Category  Count  Percentage
# 0   COVID-19     male  40368       84.28
# 1   COVID-19   female   7530       15.72
# 2  Monkeypox     male  38517       80.62
# 3  Monkeypox   female   9260       19.38

# %%
# Expanded healthcare-related keywords
healthcare_keywords = [
    "healthcare", "hospital", "clinic", "medical", "nurse", "doctor",
    "treatment", "therapy", "medication", "healthcare system",
    "trust", "reliable", "confidence", "supportive", "faith", "assurance",
    "dependable", "credibility", "trustworthy", "public health", "WHO", "CDC",
    "ministry of health", "healthcare authority", "emergency room", "ICU",
    "ventilator", "ambulance", "preparedness", "readiness", "response team",
    "care", "patient", "recovery", "healing", "well-being", "satisfaction",
    "service quality", "experience", "access", "affordability", "availability",
    "healthcare facilities", "infrastructure", "resources", "vaccine",
    "vaccination", "immunization", "prevention", "screening", "testing",
    "equity", "fairness", "ethics", "inclusivity", "community care"
]

# Filter tweets for healthcare-related terms
mpox_healthcare = mpox_df[mpox_df['processed_text_mpox'].str.contains('|'.join(healthcare_keywords), case=False, na=False)]
covid_healthcare = covid_df[covid_df['processed_text_covid'].str.contains('|'.join(healthcare_keywords), case=False, na=False)]

# Analyze sentiment distribution
covid_healthcare_sentiment = covid_healthcare['covid_sentiment'].value_counts(normalize=True)
mpox_healthcare_sentiment = mpox_healthcare['mpox_sentiment'].value_counts(normalize=True)

# Output results
print("\nCOVID Healthcare Sentiment Distribution:")
print(covid_healthcare_sentiment)

print("Monkeypox Healthcare Sentiment Distribution:")
print(mpox_healthcare_sentiment)


# Create bar chart for economic sentiment distribution comparison
labels = ['Positive', 'Neutral', 'Negative']

# COVID Economic Sentiment Distribution (convert to percentages)
covid_values = [
    covid_healthcare_sentiment.get('positive', 0) * 100,
    covid_healthcare_sentiment.get('neutral', 0) * 100,
    covid_healthcare_sentiment.get('negative', 0) * 100
]

# Monkeypox Economic Sentiment Distribution (convert to percentages)
mpox_values = [
    mpox_healthcare_sentiment.get('positive', 0) * 100,
    mpox_healthcare_sentiment.get('neutral', 0) * 100,
    mpox_healthcare_sentiment.get('negative', 0) * 100
]



# Create pie charts for economic sentiment distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))


# COVID-19 Pie Chart
axes[1].pie(covid_values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'salmon'])
axes[1].set_title('COVID-19 Health Care Sentiment')


# Monkeypox Pie Chart
axes[0].pie(mpox_values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'salmon'])
axes[0].set_title('Monkeypox Health Care Sentiment')

# Display the pie charts
plt.tight_layout()
plt.show()
# Out:
# COVID Healthcare Sentiment Distribution:
# covid_sentiment
# neutral     0.672350
# negative    0.279893
# positive    0.047757
# Name: proportion, dtype: float64
# Monkeypox Healthcare Sentiment Distribution:
# mpox_sentiment
# negative    0.700736
# positive    0.252737
# neutral     0.046528
# Name: proportion, dtype: float64

# %%
# Expanded economic impact-related keywords
economic_keywords = [
    "economy", "economic", "financial", "finance", "recession", "inflation",
    "GDP", "downturn", "economic growth", "job", "employment", "unemployment",
    "workforce", "layoffs", "furlough", "hiring", "career", "jobless",
    "labor market", "business", "company", "corporation", "industry",
    "small business", "startup", "retail", "manufacturing", "production",
    "supply chain", "stimulus", "bailout", "government aid", "subsidy",
    "funding", "relief package", "tax cuts", "economic policy", "fiscal policy",
    "monetary policy", "savings", "income", "salary", "wage", "poverty",
    "cost of living", "affordability", "budget", "debt", "expenses",
    "stock market", "stocks", "shares", "investment", "trading", "capital",
    "profit", "loss", "dividends", "recovery", "rebound", "stabilization",
    "growth", "economic boost", "improvement"
]

# Filter tweets for economic impact-related terms
covid_economic = covid_df[covid_df['processed_text_covid'].str.contains('|'.join(economic_keywords), case=False, na=False)]
mpox_economic = mpox_df[mpox_df['processed_text_mpox'].str.contains('|'.join(economic_keywords), case=False, na=False)]

# Analyze sentiment distribution
covid_economic_sentiment = covid_economic['covid_sentiment'].value_counts(normalize=True)
mpox_economic_sentiment = mpox_economic['mpox_sentiment'].value_counts(normalize=True)

# Output results
print("\nCOVID Economic Sentiment Distribution:")
print(covid_economic_sentiment)

print("Monkeypox Economic Sentiment Distribution:")
print(mpox_economic_sentiment)

# Create bar chart for economic sentiment distribution comparison
labels = ['Positive', 'Neutral', 'Negative']

# COVID Economic Sentiment Distribution (convert to percentages)
covid_values = [
    covid_economic_sentiment.get('positive', 0) * 100,
    covid_economic_sentiment.get('neutral', 0) * 100,
    covid_economic_sentiment.get('negative', 0) * 100
]

# Monkeypox Economic Sentiment Distribution (convert to percentages)
mpox_values = [
    mpox_economic_sentiment.get('positive', 0) * 100,
    mpox_economic_sentiment.get('neutral', 0) * 100,
    mpox_economic_sentiment.get('negative', 0) * 100
]

# Create pie charts for economic sentiment distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))


# COVID-19 Pie Chart
axes[1].pie(covid_values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'salmon'])
axes[1].set_title('COVID-19 Economic Sentiment')


# Monkeypox Pie Chart
axes[0].pie(mpox_values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'salmon'])
axes[0].set_title('Monkeypox Economic Sentiment')

# Display the pie charts
plt.tight_layout()
plt.show()
# Out:
# COVID Economic Sentiment Distribution:
# covid_sentiment
# neutral     0.49910
# negative    0.40414
# positive    0.09676
# Name: proportion, dtype: float64
# Monkeypox Economic Sentiment Distribution:
# mpox_sentiment
# negative    0.664459
# positive    0.300957
# neutral     0.034584
# Name: proportion, dtype: float64

# %%
# Information Source Trust Comparison
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define trusted information source-related keywords
trust_keywords = [
    "WHO", "CDC", "health ministry", "government", "officials", 
    "doctors", "scientists", "medical experts", "research", 
    "verified", "reliable source", "official", "trusted", 
    "authentic", "fact-checked", "legitimate", "credible", 
    "news outlet", "journalists", "academic", "scholarly", 
    "peer-reviewed", "public health authority"
]

# Filter tweets for trusted information source-related terms
covid_trust = covid_df[covid_df['processed_text_covid'].str.contains('|'.join(trust_keywords), case=False, na=False)]
mpox_trust = mpox_df[mpox_df['processed_text_mpox'].str.contains('|'.join(trust_keywords), case=False, na=False)]

# Analyze sentiment distribution for trusted source-related tweets
covid_trust_sentiment = covid_trust['covid_sentiment'].value_counts(normalize=True)
mpox_trust_sentiment = mpox_trust['mpox_sentiment'].value_counts(normalize=True)

# Print sentiment distributions
print("\nCOVID Trust Sentiment Distribution:")
print(covid_trust_sentiment)

print("\nMonkeypox Trust Sentiment Distribution:")
print(mpox_trust_sentiment)

# Prepare data for visualization
labels = ['Positive', 'Neutral', 'Negative']

# COVID-19 Sentiment Values
covid_values = [
    covid_trust_sentiment.get('positive', 0) * 100,
    covid_trust_sentiment.get('neutral', 0) * 100,
    covid_trust_sentiment.get('negative', 0) * 100
]

# Monkeypox Sentiment Values
mpox_values = [
    mpox_trust_sentiment.get('positive', 0) * 100,
    mpox_trust_sentiment.get('neutral', 0) * 100,
    mpox_trust_sentiment.get('negative', 0) * 100
]

# Pie Charts for Sentiment Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# COVID-19 Pie Chart
axes[0].pie(covid_values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'salmon'])
axes[0].set_title('COVID-19 Trust Sentiment')

# Monkeypox Pie Chart
axes[1].pie(mpox_values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'salmon'])
axes[1].set_title('Monkeypox Trust Sentiment')

plt.tight_layout()
plt.show()
# Out:
# COVID Trust Sentiment Distribution:
# covid_sentiment
# neutral     0.662611
# negative    0.275668
# positive    0.061721
# Name: proportion, dtype: float64
#
# Monkeypox Trust Sentiment Distribution:
# mpox_sentiment
# negative    0.720602
# positive    0.224363
# neutral     0.055035
# Name: proportion, dtype: float64

# %% [markdown]
# MPOX_XLnet

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from transformers import XLNetTokenizer, TFXLNetForSequenceClassification
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# Tokenize the text using XLNet
tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased')

# Encode Sentiment Labels
le = LabelEncoder()
mpox_df['mpox_sentiment_encoded'] = le.fit_transform(mpox_df['mpox_sentiment'])

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    mpox_df['processed_text_mpox'], 
    mpox_df['mpox_sentiment_encoded'], 
    test_size=0.2, 
    random_state=1
)

# Tokenize and prepare data for XLNet
def tokenize(text_series):
    return tokenizer(
        list(text_series), 
        padding=True, 
        truncation=True, 
        return_tensors='tf', 
        max_length=50
    )

train_encodings = tokenize(X_train)
test_encodings = tokenize(X_test)

# Convert labels to TensorFlow tensors
y_train = tf.convert_to_tensor(y_train)
y_test = tf.convert_to_tensor(y_test)

# Initialize the XLNet model
xlnet_model_mpox = TFXLNetForSequenceClassification.from_pretrained(
    'xlnet-base-cased', num_labels=3
)

# Compile the model
xlnet_model_mpox.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Train the model
history = xlnet_model_mpox.fit(
    train_encodings['input_ids'], 
    y_train, 
    validation_data=(test_encodings['input_ids'], y_test),
    epochs=3, 
    batch_size=16
)

# Evaluate the model
loss, accuracy = xlnet_model_mpox.evaluate(test_encodings['input_ids'], y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Plot Learning Curves
plt.figure(figsize=(12, 5))

# Subplot 1: Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Display plots
plt.tight_layout()
plt.show()
# Out:
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# /tmp/ipykernel_36/72841246.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   mpox_df['mpox_sentiment_encoded'] = le.fit_transform(mpox_df['mpox_sentiment'])
# I0000 00:00:1752768117.526010      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13562 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1752768117.526722      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# tf_model.h5:   0%|          | 0.00/565M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/initializers/initializers.py:121: UserWarning: The initializer TruncatedNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Some layers from the model checkpoint at xlnet-base-cased were not used when initializing TFXLNetForSequenceClassification: ['lm_loss']
# - This IS expected if you are initializing TFXLNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFXLNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFXLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj', 'sequence_summary']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752768168.359473     138 service.cc:148] XLA service 0x7a5d9cf534b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752768168.359972     138 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752768168.359992     138 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752768168.451833     138 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1752768168.571307     138 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5332/5332 [==============================] - 1265s 227ms/step - loss: 0.5234 - accuracy: 0.7913 - val_loss: 0.4892 - val_accuracy: 0.8063
# Epoch 2/3
# 5332/5332 [==============================] - 1209s 227ms/step - loss: 0.4046 - accuracy: 0.8424 - val_loss: 0.4550 - val_accuracy: 0.8318
# Epoch 3/3
# 5332/5332 [==============================] - 1207s 226ms/step - loss: 0.3299 - accuracy: 0.8751 - val_loss: 0.4572 - val_accuracy: 0.8379
# 667/667 [==============================] - 92s 131ms/step - loss: 0.4572 - accuracy: 0.8379
# Test Accuracy: 83.79%

# %% [markdown]
# CONFUSSION_MATRIX

# %%
# Predict with reduced batch size
batch_size = 8
predictions = []
for i in range(0, len(test_encodings['input_ids']), batch_size):
    batch_input_ids = test_encodings['input_ids'][i:i + batch_size]
    logits = xlnet_model_mpox.predict(batch_input_ids).logits
    predictions.extend(logits)

y_pred_probs = tf.nn.softmax(np.array(predictions), axis=1).numpy()
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Plot Learning Curves
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# ...
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# Classification Report:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/2936568897.py in <cell line: 0>()
#      21 # Classification Report
#      22 print("Classification Report:")
# ---> 23 print(classification_report(y_test, y_pred, target_names=le.classes_))
#      24
#      25 # Plot Learning Curves
#
# NameError: name 'classification_report' is not defined

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Predict with reduced batch size
batch_size = 8
predictions = []
for i in range(0, len(test_encodings['input_ids']), batch_size):
    batch_input_ids = test_encodings['input_ids'][i:i + batch_size]
    logits = xlnet_model_mpox.predict(batch_input_ids).logits
    predictions.extend(logits)

# Convert logits to predicted labels
y_pred_probs = tf.nn.softmax(np.array(predictions), axis=1).numpy()
y_pred = np.argmax(y_pred_probs, axis=1)

# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print overall performance
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")

# Detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# ...
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# Precision: 0.83
# Recall: 0.84
# F1-Score: 0.83
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.93      0.90     14668
#      neutral       0.60      0.44      0.51      1932
#     positive       0.79      0.71      0.74      4728
#
#     accuracy                           0.84     21328
#    macro avg       0.75      0.69      0.72     21328
# weighted avg       0.83      0.84      0.83     21328

# %% [markdown]
# Mpox_DISTILROBERTA

# %%
import pandas as pd
import tensorflow as tf
from transformers import RobertaTokenizer, TFDistilBertForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'covid_df' is a pandas DataFrame with 'combined_processed_text' and 'sentiment' columns
# Preprocess labels
le = LabelEncoder()
mpox_df['mpox_sentiment_encoded'] = le.fit_transform(mpox_df['mpox_sentiment'])

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    mpox_df['processed_text_mpox'], 
    mpox_df['mpox_sentiment_encoded'], 
    test_size=0.2, 
    random_state=42
)

# Initialize Roberta tokenizer
tokenizer = RobertaTokenizer.from_pretrained('distilroberta-base')

# Tokenize and prepare data for DistilRoBERTa
def tokenize(text_series, max_length=128):
    return tokenizer(
        list(text_series),
        padding=True,
        truncation=True,
        return_tensors='tf',
        max_length=max_length
    )

train_encodings = tokenize(X_train)
test_encodings = tokenize(X_test)

# Convert labels to TensorFlow tensors
y_train = tf.convert_to_tensor(y_train)
y_test = tf.convert_to_tensor(y_test)

# Initialize the DistilRoBERTa model
model = TFDistilBertForSequenceClassification.from_pretrained(
    'distilroberta-base', 
    num_labels=len(le.classes_)
)

# Learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=3e-5,
    decay_steps=1000,
    decay_rate=0.9
)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    train_encodings['input_ids'], 
    y_train, 
    validation_data=(test_encodings['input_ids'], y_test),
    epochs=3, 
    batch_size=8
)

# Evaluate the model
loss, accuracy = model.evaluate(test_encodings['input_ids'], y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Predict
y_pred_logits = model.predict(test_encodings['input_ids']).logits
y_pred = tf.argmax(y_pred_logits, axis=1).numpy()

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# Save the fine-tuned model and tokenizer
model.save_pretrained('./distilroberta_sentiment_model')
tokenizer.save_pretrained('./distilroberta_sentiment_model')

print("Model and tokenizer saved!")

# Plot Learning Curves
plt.figure(figsize=(12, 5))

# Subplot 1: Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Display plots
plt.tight_layout()
plt.show()
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# You are using a model of type roberta to instantiate a model of type distilbert. This is not supported for all configurations of models and can yield errors.
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertForSequenceClassification: ['roberta.encoder.layer.3.attention.self.query.weight', 'roberta.encoder.layer.3.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.self.query.weight', 'roberta.encoder.layer.1.intermediate.dense.bias', 'roberta.encoder.layer.1.intermediate.dense.weight', 'roberta.encoder.layer.4.output.LayerNorm.weight', 'roberta.encoder.layer.4.attention.output.dense.bias', 'roberta.encoder.layer.5.output.LayerNorm.weight', 'roberta.encoder.layer.3.attention.self.value.weight', 'roberta.encoder.layer.2.output.dense.weight', 'roberta.encoder.layer.0.output.LayerNorm.weight', 'roberta.encoder.layer.4.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.output.dense.weight', 'roberta.encoder.layer.4.output.dense.weight', 'lm_head.dense.weight', 'roberta.encoder.layer.2.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.self.query.bias', 'roberta.encoder.layer.0.output.dense.weight', 'roberta.encoder.layer.3.attention.self.value.bias', 'roberta.encoder.layer.3.attention.output.dense.weight', 'roberta.encoder.layer.5.attention.output.dense.bias', 'roberta.encoder.layer.2.attention.self.value.weight', 'roberta.encoder.layer.2.intermediate.dense.bias', 'roberta.encoder.layer.1.attention.output.dense.bias', 'roberta.encoder.layer.4.attention.self.key.bias', 'roberta.encoder.layer.5.attention.self.query.bias', 'roberta.encoder.layer.2.output.dense.bias', 'roberta.encoder.layer.0.attention.self.key.weight', 'lm_head.bias', 'roberta.encoder.layer.4.output.dense.bias', 'roberta.encoder.layer.1.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.value.bias', 'lm_head.dense.bias', 'roberta.encoder.layer.5.output.dense.weight', 'roberta.embeddings.LayerNorm.bias', 'roberta.encoder.layer.2.intermediate.dense.weight', 'roberta.encoder.layer.5.attention.output.dense.weight', 'roberta.encoder.layer.5.intermediate.dense.weight', 'roberta.encoder.layer.1.attention.output.LayerNorm.weight', 'roberta.encoder.layer.2.attention.self.key.weight', 'roberta.encoder.layer.2.attention.self.key.bias', 'roberta.encoder.layer.0.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.dense.bias', 'roberta.encoder.layer.4.attention.self.query.bias', 'roberta.encoder.layer.4.attention.self.value.bias', 'roberta.encoder.layer.3.intermediate.dense.bias', 'roberta.encoder.layer.5.attention.output.LayerNorm.weight', 'roberta.encoder.layer.4.intermediate.dense.bias', 'roberta.encoder.layer.3.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.value.weight', 'roberta.encoder.layer.4.output.LayerNorm.bias', 'roberta.encoder.layer.2.attention.output.dense.weight', 'roberta.encoder.layer.5.intermediate.dense.bias', 'roberta.encoder.layer.4.attention.self.value.weight', 'roberta.encoder.layer.4.attention.self.query.weight', 'lm_head.layer_norm.bias', 'roberta.embeddings.LayerNorm.weight', 'roberta.encoder.layer.0.intermediate.dense.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.bias', 'roberta.encoder.layer.0.attention.self.value.weight', 'roberta.encoder.layer.4.attention.self.key.weight', 'roberta.encoder.layer.0.output.LayerNorm.bias', 'roberta.embeddings.word_embeddings.weight', 'roberta.encoder.layer.0.attention.self.value.bias', 'roberta.encoder.layer.1.output.dense.weight', 'roberta.encoder.layer.3.attention.output.dense.bias', 'roberta.encoder.layer.1.output.LayerNorm.bias', 'roberta.encoder.layer.3.attention.output.LayerNorm.weight', 'roberta.encoder.layer.2.attention.self.value.bias', 'roberta.encoder.layer.5.attention.self.query.weight', 'roberta.encoder.layer.2.output.LayerNorm.weight', 'roberta.pooler.dense.bias', 'roberta.encoder.layer.1.attention.self.value.bias', 'roberta.encoder.layer.0.attention.output.dense.weight', 'roberta.encoder.layer.4.attention.output.dense.weight', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'roberta.encoder.layer.3.at ...
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFDistilBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['embeddings.word_embeddings.weight', 'embeddings.position_embeddings.weight', 'embeddings.LayerNorm.weight', 'embeddings.LayerNorm.bias', 'transformer.layer.0.attention.q_lin.weight', 'transformer.layer.0.attention.q_lin.bias', 'transformer.layer.0.attention.k_lin.weight', 'transformer.layer.0.attention.k_lin.bias', 'transformer.layer.0.attention.v_lin.weight', 'transformer.layer.0.attention.v_lin.bias', 'transformer.layer.0.attention.out_lin.weight', 'transformer.layer.0.attention.out_lin.bias', 'transformer.layer.0.sa_layer_norm.weight', 'transformer.layer.0.sa_layer_norm.bias', 'transformer.layer.0.ffn.lin1.weight', 'transformer.layer.0.ffn.lin1.bias', 'transformer.layer.0.ffn.lin2.weight', 'transformer.layer.0.ffn.lin2.bias', 'transformer.layer.0.output_layer_norm.weight', 'transformer.layer.0.output_layer_norm.bias', 'transformer.layer.1.attention.q_lin.weight', 'transformer.layer.1.attention.q_lin.bias', 'transformer.layer.1.attention.k_lin.weight', 'transformer.layer.1.attention.k_lin.bias', 'transformer.layer.1.attention.v_lin.weight', 'transformer.layer.1.attention.v_lin.bias', 'transformer.layer.1.attention.out_lin.weight', 'transformer.layer.1.attention.out_lin.bias', 'transformer.layer.1.sa_layer_norm.weight', 'transformer.layer.1.sa_layer_norm.bias', 'transformer.layer.1.ffn.lin1.weight', 'transformer.layer.1.ffn.lin1.bias', 'transformer.layer.1.ffn.lin2.weight', 'transformer.layer.1.ffn.lin2.bias', 'transformer.layer.1.output_layer_norm.weight', 'transformer.layer.1.output_layer_norm.bias', 'transformer.layer.2.attention.q_lin.weight', 'transformer.layer.2.attention.q_lin.bias', 'transformer.layer.2.attention.k_lin.weight', 'transformer.layer.2.attention.k_lin.bias', 'transformer.layer.2.attention.v_lin.weight', 'transformer.layer.2.attention.v_lin.bias', 'transformer.layer.2.attention.out_lin.weight', 'transformer.layer.2.attention.out_lin.bias', 'transformer.layer.2.sa_layer_norm.weight', 'transformer.layer.2.sa_layer_norm.bias', 'transformer.layer.2.ffn.lin1.weight', 'transformer.layer.2.ffn.lin1.bias', 'transformer.layer.2.ffn.lin2.weight', 'transformer.layer.2.ffn.lin2.bias', 'transformer.layer.2.output_layer_norm.weight', 'transformer.layer.2.output_layer_norm.bias', 'transformer.layer.3.attention.q_lin.weight', 'transformer.layer.3.attention.q_lin.bias', 'transformer.layer.3.attention.k_lin.weight', 'transformer.layer.3.attention.k_lin.bias', 'transformer.layer.3.attention.v_lin.weight', 'transformer.layer.3.attention.v_lin.bias', 'transformer.layer.3.attention.out_lin.weight', 'transformer.layer.3.attention.out_lin.bias', 'transformer.layer.3.sa_layer_norm.weight', 'transformer.layer.3.sa_layer_norm.bias', 'transformer.layer.3.ffn.lin1.weight', 'transformer.layer.3.ffn.lin1.bias', 'transformer.layer.3.ffn.lin2.weight', 'transformer.layer.3.ffn.lin2.bias', 'transformer.layer.3.output_layer_norm.weight', 'transformer.layer.3.output_layer_norm.bias', 'transformer.layer.4.attention.q_lin.weight', 'transformer.layer.4.attention.q_lin.bias', 'transformer.layer.4.attention.k_lin.weight', 'transformer.layer.4.attention.k_lin.bias', 'transformer.layer.4.attention.v_lin.weight', 'transformer.layer.4.attention.v_lin.bias', 'transformer.layer.4.attention.out_lin.weight', 'transformer.layer.4.attention.out_lin.bias', 'transformer.layer.4.sa_layer_norm.weight', 'transformer.layer.4.sa_layer_norm.bias', 'transformer.layer.4.ffn.lin1.weight', 'transformer.layer.4.ffn.lin1.bias', 'transformer.layer.4.ffn.lin2.weight', 'transformer.layer.4.ffn.lin2.bias', 'transformer.layer.4.output_layer_norm.weight', 'transformer.layer.4.output_layer_norm.bias', 'transformer.layer.5.attention.q_lin.weight', 'transformer.layer.5.attention.q_lin.bias', 'transformer.layer.5.attention.k_lin.weight', 'transformer.layer.5.attention.k_lin.bias', 'transformer.layer.5.attention.v_lin.weight', 't ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3
# 10664/10664 [==============================] - 1415s 130ms/step - loss: 0.6091 - accuracy: 0.7528 - val_loss: 0.4754 - val_accuracy: 0.8036
# Epoch 2/3
# 10664/10664 [==============================] - 1379s 129ms/step - loss: 0.4076 - accuracy: 0.8349 - val_loss: 0.4476 - val_accuracy: 0.8203
# Epoch 3/3
# 10664/10664 [==============================] - 1383s 130ms/step - loss: 0.3447 - accuracy: 0.8605 - val_loss: 0.4449 - val_accuracy: 0.8250
# 667/667 [==============================] - 98s 143ms/step - loss: 0.4449 - accuracy: 0.8250
# Accuracy: 82.50%
# 667/667 [==============================] - 98s 142ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.93      0.89     14705
#      neutral       0.71      0.50      0.59      2000
#     positive       0.72      0.65      0.68      4623
#
#     accuracy                           0.83     21328
#    macro avg       0.77      0.69      0.72     21328
# weighted avg       0.82      0.83      0.82     21328
# Model and tokenizer saved!

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Predict labels for the test set
y_pred_probs = model.predict(test_encodings['input_ids']).logits
y_pred = tf.argmax(y_pred_probs, axis=1).numpy()

# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print overall performance metrics
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")

# Generate a detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Confusion Matrix
conf_matrix = tf.math.confusion_matrix(y_test, y_pred).numpy()
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 667/667 [==============================] - 95s 142ms/step
# Precision: 0.82
# Recall: 0.83
# F1-Score: 0.82
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.93      0.89     14705
#      neutral       0.71      0.50      0.59      2000
#     positive       0.72      0.65      0.68      4623
#
#     accuracy                           0.83     21328
#    macro avg       0.77      0.69      0.72     21328
# weighted avg       0.82      0.83      0.82     21328

# %%
import pandas as pd
import tensorflow as tf
from transformers import RobertaTokenizer, TFDistilBertForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming 'hmpv_df' is a pandas DataFrame with 'processed_text_hmpv' and 'hmpv_sentiment' columns

# Encode sentiment labels
le = LabelEncoder()
mpox_df['mpox_sentiment_encoded'] = le.fit_transform(mpox_df['mpox_sentiment'])

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    mpox_df['processed_text_mpox'],
    mpox_df['mpox_sentiment_encoded'],
    test_size=0.2,
    random_state=42
)

# Initialize Roberta tokenizer
tokenizer = RobertaTokenizer.from_pretrained('distilroberta-base')

# Tokenization function
def tokenize(text_series, max_length=128):
    return tokenizer(
        list(text_series),
        padding=True,
        truncation=True,
        return_tensors='tf',
        max_length=max_length
    )

# Tokenize text
train_encodings = tokenize(X_train)
test_encodings = tokenize(X_test)

# Convert labels to tensors
y_train_tensor = tf.convert_to_tensor(y_train)
y_test_tensor = tf.convert_to_tensor(y_test)

# Initialize DistilBERT model
model = TFDistilBertForSequenceClassification.from_pretrained(
    'distilroberta-base',
    num_labels=len(le.classes_)
)

# Learning rate scheduler
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=3e-5,
    decay_steps=1000,
    decay_rate=0.9
)

# Compile model
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_encodings['input_ids'],
    y_train_tensor,
    validation_data=(test_encodings['input_ids'], y_test_tensor),
    epochs=4,
    batch_size=8
)

# Evaluate accuracy
loss, accuracy = model.evaluate(test_encodings['input_ids'], y_test_tensor)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Predict
y_pred_logits = model.predict(test_encodings['input_ids']).logits
y_pred = tf.argmax(y_pred_logits, axis=1).numpy()
y_true = y_test_tensor.numpy()

# Precision, Recall, F1
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# Save model and tokenizer
model.save_pretrained('./distilroberta_sentiment_model')
tokenizer.save_pretrained('./distilroberta_sentiment_model')

print("Model and tokenizer saved!")
# Out:
# You are using a model of type roberta to instantiate a model of type distilbert. This is not supported for all configurations of models and can yield errors.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertForSequenceClassification: ['roberta.encoder.layer.3.attention.self.query.weight', 'roberta.encoder.layer.3.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.self.query.weight', 'roberta.encoder.layer.1.intermediate.dense.bias', 'roberta.encoder.layer.1.intermediate.dense.weight', 'roberta.encoder.layer.4.output.LayerNorm.weight', 'roberta.encoder.layer.4.attention.output.dense.bias', 'roberta.encoder.layer.5.output.LayerNorm.weight', 'roberta.encoder.layer.3.attention.self.value.weight', 'roberta.encoder.layer.2.output.dense.weight', 'roberta.encoder.layer.0.output.LayerNorm.weight', 'roberta.encoder.layer.4.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.output.dense.weight', 'roberta.encoder.layer.4.output.dense.weight', 'lm_head.dense.weight', 'roberta.encoder.layer.2.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.self.query.bias', 'roberta.encoder.layer.0.output.dense.weight', 'roberta.encoder.layer.3.attention.self.value.bias', 'roberta.encoder.layer.3.attention.output.dense.weight', 'roberta.encoder.layer.5.attention.output.dense.bias', 'roberta.encoder.layer.2.attention.self.value.weight', 'roberta.encoder.layer.2.intermediate.dense.bias', 'roberta.encoder.layer.1.attention.output.dense.bias', 'roberta.encoder.layer.4.attention.self.key.bias', 'roberta.encoder.layer.5.attention.self.query.bias', 'roberta.encoder.layer.2.output.dense.bias', 'roberta.encoder.layer.0.attention.self.key.weight', 'lm_head.bias', 'roberta.encoder.layer.4.output.dense.bias', 'roberta.encoder.layer.1.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.value.bias', 'lm_head.dense.bias', 'roberta.encoder.layer.5.output.dense.weight', 'roberta.embeddings.LayerNorm.bias', 'roberta.encoder.layer.2.intermediate.dense.weight', 'roberta.encoder.layer.5.attention.output.dense.weight', 'roberta.encoder.layer.5.intermediate.dense.weight', 'roberta.encoder.layer.1.attention.output.LayerNorm.weight', 'roberta.encoder.layer.2.attention.self.key.weight', 'roberta.encoder.layer.2.attention.self.key.bias', 'roberta.encoder.layer.0.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.dense.bias', 'roberta.encoder.layer.4.attention.self.query.bias', 'roberta.encoder.layer.4.attention.self.value.bias', 'roberta.encoder.layer.3.intermediate.dense.bias', 'roberta.encoder.layer.5.attention.output.LayerNorm.weight', 'roberta.encoder.layer.4.intermediate.dense.bias', 'roberta.encoder.layer.3.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.value.weight', 'roberta.encoder.layer.4.output.LayerNorm.bias', 'roberta.encoder.layer.2.attention.output.dense.weight', 'roberta.encoder.layer.5.intermediate.dense.bias', 'roberta.encoder.layer.4.attention.self.value.weight', 'roberta.encoder.layer.4.attention.self.query.weight', 'lm_head.layer_norm.bias', 'roberta.embeddings.LayerNorm.weight', 'roberta.encoder.layer.0.intermediate.dense.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.bias', 'roberta.encoder.layer.0.attention.self.value.weight', 'roberta.encoder.layer.4.attention.self.key.weight', 'roberta.encoder.layer.0.output.LayerNorm.bias', 'roberta.embeddings.word_embeddings.weight', 'roberta.encoder.layer.0.attention.self.value.bias', 'roberta.encoder.layer.1.output.dense.weight', 'roberta.encoder.layer.3.attention.output.dense.bias', 'roberta.encoder.layer.1.output.LayerNorm.bias', 'roberta.encoder.layer.3.attention.output.LayerNorm.weight', 'roberta.encoder.layer.2.attention.self.value.bias', 'roberta.encoder.layer.5.attention.self.query.weight', 'roberta.encoder.layer.2.output.LayerNorm.weight', 'roberta.pooler.dense.bias', 'roberta.encoder.layer.1.attention.self.value.bias', 'roberta.encoder.layer.0.attention.output.dense.weight', 'roberta.encoder.layer.4.attention.output.dense.weight', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'roberta.encoder.layer.3.at ...
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFDistilBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['embeddings.word_embeddings.weight', 'embeddings.position_embeddings.weight', 'embeddings.LayerNorm.weight', 'embeddings.LayerNorm.bias', 'transformer.layer.0.attention.q_lin.weight', 'transformer.layer.0.attention.q_lin.bias', 'transformer.layer.0.attention.k_lin.weight', 'transformer.layer.0.attention.k_lin.bias', 'transformer.layer.0.attention.v_lin.weight', 'transformer.layer.0.attention.v_lin.bias', 'transformer.layer.0.attention.out_lin.weight', 'transformer.layer.0.attention.out_lin.bias', 'transformer.layer.0.sa_layer_norm.weight', 'transformer.layer.0.sa_layer_norm.bias', 'transformer.layer.0.ffn.lin1.weight', 'transformer.layer.0.ffn.lin1.bias', 'transformer.layer.0.ffn.lin2.weight', 'transformer.layer.0.ffn.lin2.bias', 'transformer.layer.0.output_layer_norm.weight', 'transformer.layer.0.output_layer_norm.bias', 'transformer.layer.1.attention.q_lin.weight', 'transformer.layer.1.attention.q_lin.bias', 'transformer.layer.1.attention.k_lin.weight', 'transformer.layer.1.attention.k_lin.bias', 'transformer.layer.1.attention.v_lin.weight', 'transformer.layer.1.attention.v_lin.bias', 'transformer.layer.1.attention.out_lin.weight', 'transformer.layer.1.attention.out_lin.bias', 'transformer.layer.1.sa_layer_norm.weight', 'transformer.layer.1.sa_layer_norm.bias', 'transformer.layer.1.ffn.lin1.weight', 'transformer.layer.1.ffn.lin1.bias', 'transformer.layer.1.ffn.lin2.weight', 'transformer.layer.1.ffn.lin2.bias', 'transformer.layer.1.output_layer_norm.weight', 'transformer.layer.1.output_layer_norm.bias', 'transformer.layer.2.attention.q_lin.weight', 'transformer.layer.2.attention.q_lin.bias', 'transformer.layer.2.attention.k_lin.weight', 'transformer.layer.2.attention.k_lin.bias', 'transformer.layer.2.attention.v_lin.weight', 'transformer.layer.2.attention.v_lin.bias', 'transformer.layer.2.attention.out_lin.weight', 'transformer.layer.2.attention.out_lin.bias', 'transformer.layer.2.sa_layer_norm.weight', 'transformer.layer.2.sa_layer_norm.bias', 'transformer.layer.2.ffn.lin1.weight', 'transformer.layer.2.ffn.lin1.bias', 'transformer.layer.2.ffn.lin2.weight', 'transformer.layer.2.ffn.lin2.bias', 'transformer.layer.2.output_layer_norm.weight', 'transformer.layer.2.output_layer_norm.bias', 'transformer.layer.3.attention.q_lin.weight', 'transformer.layer.3.attention.q_lin.bias', 'transformer.layer.3.attention.k_lin.weight', 'transformer.layer.3.attention.k_lin.bias', 'transformer.layer.3.attention.v_lin.weight', 'transformer.layer.3.attention.v_lin.bias', 'transformer.layer.3.attention.out_lin.weight', 'transformer.layer.3.attention.out_lin.bias', 'transformer.layer.3.sa_layer_norm.weight', 'transformer.layer.3.sa_layer_norm.bias', 'transformer.layer.3.ffn.lin1.weight', 'transformer.layer.3.ffn.lin1.bias', 'transformer.layer.3.ffn.lin2.weight', 'transformer.layer.3.ffn.lin2.bias', 'transformer.layer.3.output_layer_norm.weight', 'transformer.layer.3.output_layer_norm.bias', 'transformer.layer.4.attention.q_lin.weight', 'transformer.layer.4.attention.q_lin.bias', 'transformer.layer.4.attention.k_lin.weight', 'transformer.layer.4.attention.k_lin.bias', 'transformer.layer.4.attention.v_lin.weight', 'transformer.layer.4.attention.v_lin.bias', 'transformer.layer.4.attention.out_lin.weight', 'transformer.layer.4.attention.out_lin.bias', 'transformer.layer.4.sa_layer_norm.weight', 'transformer.layer.4.sa_layer_norm.bias', 'transformer.layer.4.ffn.lin1.weight', 'transformer.layer.4.ffn.lin1.bias', 'transformer.layer.4.ffn.lin2.weight', 'transformer.layer.4.ffn.lin2.bias', 'transformer.layer.4.output_layer_norm.weight', 'transformer.layer.4.output_layer_norm.bias', 'transformer.layer.5.attention.q_lin.weight', 'transformer.layer.5.attention.q_lin.bias', 'transformer.layer.5.attention.k_lin.weight', 'transformer.layer.5.attention.k_lin.bias', 'transformer.layer.5.attention.v_lin.weight', 't ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/4
# 10664/10664 [==============================] - 1410s 130ms/step - loss: 0.6044 - accuracy: 0.7548 - val_loss: 0.4778 - val_accuracy: 0.8043
# Epoch 2/4
# 10664/10664 [==============================] - 1380s 129ms/step - loss: 0.4039 - accuracy: 0.8351 - val_loss: 0.4459 - val_accuracy: 0.8215
# Epoch 3/4
#  9924/10664 [==========================>...] - ETA: 1:29 - loss: 0.3401 - accuracy: 0.8625
